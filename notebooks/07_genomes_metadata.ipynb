# %% [markdown]
# # Goal
# Jacobo de la Cuesta-Zuluaga, July 2018.
#
# Previously, I downloaded all the available *Methanomassiliicoccales* assemblies from NCBI, and ran `CheckM` to determine which were considered at least *substantially complete genomes* (>= 70%) *with low contamination* (<= 5%). I started doing several genome and phylogenimic comparisons between the available genomes and the draft of *Ca* Methanomethylophilus alvus RL001, but for analysis of phylogenetic signal, I require some metadata of the available genomes, in particular, the source from which it was obtained.

# %% [markdown]
# # Var

# %%
metadata_folder = "/ebio/abt3_projects/vadinCA11/data/V11/assemblies_metadata"

# %% [markdown]
# # Init

# %%
library(dplyr)

# %% [markdown]
# # Create metadata table

# %% [markdown]
# ## CheckM genome quality data

# %% [markdown]
# Load table with organism name and NCBI assembly accession

# %%
# Load table
label_table = read.table("/ebio/abt3_projects/vadinCA11/data/V11/anvio_output/external_genomes.txt",
                       header = T, sep = "\t", as.is = T)

label_table$contigs_db_path = label_table$contigs_db_path %>% 
  as.vector %>% lapply(. , function(x) basename(x) %>% strsplit(., ".db", fixed = T)) %>%
  unlist

# %% [markdown]
# Generate table with CheckM data, including GC content, numer of genes and genome length

# %%
# Load CheckM metadata
checkm_metadata = read.table("/ebio/abt3_projects/vadinCA11/data/V11/genomes/included_stats.txt",
                             sep = "\t", dec = ".", header = T, row.names = 1,
                             as.is = T, comment.char = "")

# Change assembly names
colnames(checkm_metadata) = colnames(checkm_metadata) %>% 
  lapply(. , function(x) strsplit(x, "\\.[0-9]", perl =  T)) %>% unlist

# Create a data frame with GC content and genome length
Assembly = colnames(checkm_metadata) %>% as.character()
GC = checkm_metadata["GC",] %>% as.numeric %>% unlist
Len = checkm_metadata["Genome size",] %>% as.numeric %>% unlist
Genes = checkm_metadata["# predicted genes",] %>% as.numeric %>% unlist
methanomassilii_data = data.frame(Assembly, GC = GC, Len = Len, 
                                  Genes, stringsAsFactors = F)

methanomassilii_data = methanomassilii_data[match(label_table$contigs_db_path, methanomassilii_data$Assembly), ]
row.names(methanomassilii_data) = label_table$name

# %%
methanomassilii_data %>% head
# Out:
#                                                           Assembly
# Methanomassiliicoccus_luminyensis_B10                     GCA_000308215
# Candidatus_Methanomethylophilus_alvus_Mx1201              GCA_000300255
# Candidatus_Methanomassiliicoccus_intestinalis_Issoire_Mx1 GCA_000404225
# Candidatus_Methanoplasma_termitum                         GCA_000800805
# Candidatus_Methanomethylophilus_sp_1R26                   GCA_001481295
# Methanomassiliicoccales_archaeon_RumEn_M2                 GCA_001421175
#                                                           GC        Len
# Methanomassiliicoccus_luminyensis_B10                     0.6047886 2620233
# Candidatus_Methanomethylophilus_alvus_Mx1201              0.5559482 1666795
# Candidatus_Methanomassiliicoccus_intestinalis_Issoire_Mx1 0.4125543 1931651
# Candidatus_Methanoplasma_termitum                         0.4920570 1488669
# Candidatus_Methanomethylophilus_sp_1R26                   0.6039454 1723106
# Methanomassiliicoccales_archaeon_RumEn_M2                 0.5460069 1280797
#                                                           Genes
# Methanomassiliicoccus_luminyensis_B10                     2607
# Candidatus_Methanomethylophilus_alvus_Mx1201              1636
# Candidatus_Methanomassiliicoccus_intestinalis_Issoire_Mx1 1855
# Candidatus_Methanoplasma_termitum                         1419
# Candidatus_Methanomethylophilus_sp_1R26                   2079
# Methanomassiliicoccales_archaeon_RumEn_M2                 1497

# %% [markdown]
# ## Source of microorganism

# %%
# Create empty columns
methanomassilii_data$source_1 = rep(NA, nrow(methanomassilii_data))
methanomassilii_data$source_2 = rep(NA, nrow(methanomassilii_data))
methanomassilii_data$location = rep(NA, nrow(methanomassilii_data))

# %% [markdown]
# ### UBA genomes
# These genomes were reported by Parks et al. and the source can be found in tables S1 and S2 of the paper

# %%
# Extract UBA codes from organism names
UBA_genomes = rownames(methanomassilii_data)[grepl("UBA", rownames(methanomassilii_data), perl = T)]
UBA_codes = UBA_genomes %>% lapply(. , function(x) strsplit(x, "_", fixed = T)) %>% unlist
UBA_codes = UBA_codes[lapply(UBA_codes , function(x) grepl(pattern = "UBA", x, perl = T)) %>% unlist]
UBA_table = data.frame(name = UBA_genomes, UBA = UBA_codes)                             
UBA_codes
# Out:
#  [1] "UBA409" "UBA238" "UBA482" "UBA593" "UBA394" "UBA292" "UBA378" "UBA382"
#  [9] "UBA147" "UBA407" "UBA408" "UBA472" "UBA309" "UBA483" "UBA393" "UBA386"
# [17] "UBA421" "UBA317" "UBA271" "UBA404" "UBA343" "UBA400" "UBA399" "UBA280"
# [25] "UBA321" "UBA296" "UBA415" "UBA358" "UBA414" "UBA381" "UBA335" "UBA78"
# [33] "UBA315" "UBA75"  "UBA481" "UBA71"  "UBA537" "UBA345" "UBA306" "UBA429"
# [41] "UBA422" "UBA371" "UBA370" "UBA113" "UBA314" "UBA480" "UBA333" "UBA329"
# [49] "UBA328" "UBA248" "UBA427" "UBA6"   "UBA364" "UBA360" "UBA48"  "UBA344"
# [57] "UBA72"  "UBA319" "UBA359" "UBA308"

# %%
# Load tables from Parks et al.
# Table S1
parks_s1 = file.path(metadata_folder, "Parks_S1.txt") %>% 
    read.table(., sep = "\t", dec = ",", na.strings="", header = T, fill = T, quote = "")

head(parks_s1)
# Out:
#   SRA.Experiment.Accession
# 1 DRX003681
# 2 DRX003682
# 3 DRX011531
# 4 DRX011532
# 5 DRX012718
# 6 ERX1064483
#   Experiment.Title
# 1 Seabass metagenomes as control2
# 2 Seabass metagenomes challenged with fast condition
# 3 High-throughput sequencing of the metagenome extracted from AM-anode biofilm
# 4 High-throughput sequencing of the metagenome extracted from GM-anode biofilm
# 5 Metagenomic sequencing of anode biofilm
# 6 Illumina HiSeq 2500 paired end sequencing
#   Library.Source
# 1 METAGENOMIC
# 2 METAGENOMIC
# 3 METAGENOMIC
# 4 METAGENOMIC
# 5 METAGENOMIC
# 6 METAGENOMIC
#   Sample.Attribute
# 1 None
# 2 None
# 3 sample_name: DRS011376 || sample comment: Anode-biofilm in acetate-fed MFC || BioSampleModel: Generic
# 4 sample_name: DRS011377 || sample comment: Anode-biofilm in glucose-fed MFC || BioSampleModel: Generic
# 5 sample_name: DRS012489 || sample comment: Total genomic DNA extracted from the anode biofilm in the methanol-fed MFC || BioSampleModel: Generic
# 6 None
#   Study.Accession
# 1 DRP000969
# 2 DRP000969
# 3 DRP001053
# 4 DRP001053
# 5 DRP001235
# 6 ERP011577
#   Study.Title
# 1 Asian seabass metagenomes in response to different stressors
# 2 Asian seabass metagenomes in response to different stressors
# 3 Comparative metagenome analyses of anode-associated microbial communities developed in rice paddy field-soil microbial fuel cells
# 4 Comparative metagenome analyses of anode-associated microbial communities developed in rice paddy field-soil microbial fuel cells
# 5 Metagenomic analyses of microbial communities generating electricity from methanol
# 6 The rumen microbial metagenome associated with high methane production in cattle

# %%
# Table S2
parks_s2 = file.path(metadata_folder, "Parks_S2.txt") %>% 
    read.table(., sep = "\t", dec = ",", na.strings="", header = T, fill = T, quote = "")
head(parks_s2)
# Out:
#   DDBJ.ENA.GenBank.Accession UBA.Genome.ID SRA.Bin.ID Genome.Quality
# 1 DAQG00000000               UBA1          SRX993396  Near complete
# 2 DAQH00000000               UBA2          SRX993396  Medium
# 3 DAMY00000000               UBA3          ERX556017  Partial
# 4 DAFQ00000000               UBA4          ERX556017  Partial
# 5 DAVG00000000               UBA5          DRX011531  Near complete
# 6 DAVH00000000               UBA6          DRX011531  Near complete
#   CheckM.Completeness CheckM.Contamination CheckM.Strain.Heterogeneity
# 1 98.85               1.32                 40
# 2 89.22               0.00                  0
# 3 52.10               0.00                  0
# 4 55.47               0.00                  0
# 5 98.69               0.33                  0
# 6 97.31               0.81                  0
#   NCBI.Organism.Name
# 1 Methanosaeta harundinacea UBA1 [species]
# 2 Methanomicrobiaceae archaeon UBA2 [family]
# 3 Euryarchaeota archaeon UBA3 [phylum]
# 4 Euryarchaeota archaeon UBA4 [phylum]
# 5 Methanosarcina sp. UBA5 [genus]
# 6 Methanomassiliicoccus sp. UBA6 [genus]

# %%
# Subset table S2 to Methanomassilii genomes
UBA_bin_ID = parks_s2[parks_s2$UBA.Genome.ID %in% UBA_codes,]
head(UBA_bin_ID)
# Out:
#    DDBJ.ENA.GenBank.Accession UBA.Genome.ID SRA.Bin.ID Genome.Quality
# 6  DAVH00000000               UBA6          DRX011531  Near complete
# 48 DACS00000000               UBA48         SRX834663  Medium
# 71 DARO00000000               UBA71         ERX250271  Near complete
# 72 DAVO00000000               UBA72         ERX250271  Near complete
# 75 DASL00000000               UBA75         ERX250271  Near complete
# 78 DARY00000000               UBA78         ERX250271  Medium
#    CheckM.Completeness CheckM.Contamination CheckM.Strain.Heterogeneity
# 6  97.31               0.81                  0
# 48 85.89               0.94                 50
# 71 97.98               0.00                  0
# 72 93.15               0.00                  0
# 75 96.91               0.00                  0
# 78 88.38               0.94                  0
#    NCBI.Organism.Name
# 6  Methanomassiliicoccus sp. UBA6 [genus]
# 48 Methanomassiliicoccaceae archaeon UBA48 [family]
# 71 Methanomassiliicoccaceae archaeon UBA71 [family]
# 72 Methanomassiliicoccaceae archaeon UBA72 [family]
# 75 Methanomassiliicoccaceae archaeon UBA75 [family]
# 78 Candidatus Methanomethylophilus sp. UBA78 [genus]

# %%
# Extract SRA bin ID from table S2 and match it with studies in table S1 to obtain source of genome
UBA_source = parks_s1[match(UBA_bin_ID$SRA.Bin.ID, parks_s1$SRA.Experiment.Accession), ]
UBA_source$UBA = UBA_bin_ID$UBA.Genome.ID
UBA_source
# Out:
#       SRA.Experiment.Accession
# 3     DRX011531
# 1491  SRX834663
# 26    ERX250271
# 26.1  ERX250271
# 26.2  ERX250271
# 26.3  ERX250271
# 774   SRX498681
# 688   SRX327722
# 15    ERX1109758
# 633   SRX211001
# 1490  SRX834662
# 797   SRX559915
# 848   SRX691273
# 847   SRX691272
# 845   SRX691270
# 845.1 SRX691270
# 845.2 SRX691270
# 852   SRX691277
# 852.1 SRX691277
# 851   SRX691276
# 851.1 SRX691276
# 851.2 SRX691276
# 850   SRX691275
# 850.1 SRX691275
# 849   SRX691274
# 854   SRX691279
# 853   SRX691278
# 853.1 SRX691278
# 853.2 SRX691278
# 840   SRX691265
# 840.1 SRX691265
# 840.2 SRX691265
# 841   SRX691266
# 842   SRX691267
# 842.1 SRX691267
# 838   SRX691263
# 838.1 SRX691263
# 838.2 SRX691263
# 858   SRX691283
# 857   SRX691282
# 857.1 SRX691282
# 855   SRX691280
# 855.1 SRX691280
# 856   SRX691281
# 856.1 SRX691281
# 856.2 SRX691281
# 856.3 SRX691281
# 861   SRX691286
# 861.1 SRX691286
# 859   SRX691284
# 859.1 SRX691284
# 860   SRX691285
# 860.1 SRX691285
# 686   SRX327521
# 1455  SRX834625
# 1453  SRX834623
# 1452  SRX834622
# 1451  SRX834621
# 1463  SRX834633
# 843   SRX691268
#       Experiment.Title
# 3     High-throughput sequencing of the metagenome extracted from AM-anode biofilm
# 1491  shotgun metagenomic sequencing of fecal sample from an adult baboon: Sample F29
# 26    None
# 26.1  None
# 26.2  None
# 26.3  None
# 774   Metagenome raw reads obatined from feces of a six-years old elephant
# 688   2012TP6_6m: suncor tailing pond 6 meters illumina sample
# 15    Illumina HiSeq 2000 paired end sequencing
# 633   NapDC illumina metagenome: Naphthaline degrading microbial community from Northern Alberta Oil Sands
# 1490  shotgun metagenomic sequencing of fecal sample from an adult baboon: Sample M16
# 797   2012TP5 illumina
# 848   Metagenomic study of ancient fermentation pits
# 847   Metagenomic study of ancient fermentation pits
# 845   Metagenomic study of ancient fermentation pits
# 845.1 Metagenomic study of ancient fermentation pits
# 845.2 Metagenomic study of ancient fermentation pits
# 852   Metagenomic study of ancient fermentation pits
# 852.1 Metagenomic study of ancient fermentation pits
# 851   Metagenomic study of ancient fermentation pits
# 851.1 Metagenomic study of ancient fermentation pits
# 851.2 Metagenomic study of ancient fermentation pits
# 850   Metagenomic study of ancient fermentation pits
# 850.1 Metagenomic study of ancient fermentation pits
# 849   Metagenomic study of ancient fermentation pits
# 854   Metagenomic study of ancient fermentation pits
# 853   Metagenomic study of ancient fermentation pits
# 853.1 Metagenomic study of ancient fermentation pits
# 853.2 Metagenomic study of ancient fermentation pits
# 840   Metagenomic study of ancient fermentation pits
# 840.1 Metagenomic study of ancient fermentation pits
# 840.2 Metagenomic study of ancient fermentation pits
# 841   Metagenomic study of ancient fermentation pits
# 842   Metagenomic study of ancient fermentation pits
# 842.1 Metagenomic study of ancient fermentation pits
# 838   Metagenomic study of ancient fermentation pits
# 838.1 Metagenomic study of ancient fermentation pits
# 838.2 Metagenomic study of ancient fermentation pits
# 858   Metagenomic study of ancient fermentation pits
# 857   Metagenomic study of ancient fermentation pits
# 857.1 Metagenomic study of ancient fermentation pits
# 855   Metagenomic study of ancient fermentation pits
# 855.1 Metagenomic study of ancient fermentation pits
# 856   Metagenomic study of ancient fermentation pits
# 856.1 Metagenomic study of ancient fermentation pits
# 856.2 Metagenomic study of ancient fermentation pits
# 856.3 Metagenomic study of ancient fermentation pits
# 861   Metagenomic study of ancient fermentation pits
# 861.1 Metagenomic study of ancient fermentation pits
# 859   Metagenomic study of ancient fermentation pits
# 859.1 Metagenomic study of ancient fermentation pits
# 860   Metagenomic study of ancient fermentation pits
# 860.1 Metagenomic study of ancient fermentation pits
# 686   Toluene illumina:Toluene degrading microbial community from hydrocarbon contaminated site
# 1455  shotgun metagenomic sequencing of fecal sample from an adult baboon: Sample F02
# 1453  shotgun metagenomic sequencing of fecal sample from an adult baboon: Sample M05
# 1452  shotgun metagenomic sequencing of fecal sample from an adult baboon: Sample M04
# 1451  shotgun metagenomic sequencing of fecal sample from an adult baboon: Sample M03
# 1463  shotgun metagenomic sequencing of fecal sample from an adult baboon: Sample M09
# 843   Metagenomic study of ancient fermentation pits
#       Library.Source
# 3     METAGENOMIC
# 1491  METAGENOMIC
# 26    METAGENOMIC
# 26.1  METAGENOMIC
# 26.2  METAGENOMIC
# 26.3  METAGENOMIC
# 774   METAGENOMIC
# 688   METAGENOMIC
# 15    METAGENOMIC
# 633   METAGENOMIC
# 1490  METAGENOMIC
# 797   METAGENOMIC
# 848   METAGENOMIC
# 847   METAGENOMIC
# 845   METAGENOMIC
# 845.1 METAGENOMIC
# 845.2 METAGENOMIC
# 852   METAGENOMIC
# 852.1 METAGENOMIC
# 851   METAGENOMIC
# 851.1 METAGENOMIC
# 851.2 METAGENOMIC
# 850   METAGENOMIC
# 850.1 METAGENOMIC
# 849   METAGENOMIC
# 854   METAGENOMIC
# 853   METAGENOMIC
# 853.1 METAGENOMIC
# 853.2 METAGENOMIC
# 840   METAGENOMIC
# 840.1 METAGENOMIC
# 840.2 METAGENOMIC
# 841   METAGENOMIC
# 842   METAGENOMIC
# 842.1 METAGENOMIC
# 838   METAGENOMIC
# 838.1 METAGENOMIC
# 838.2 METAGENOMIC
# 858   METAGENOMIC
# 857   METAGENOMIC
# 857.1 METAGENOMIC
# 855   METAGENOMIC
# 855.1 METAGENOMIC
# 856   METAGENOMIC
# 856.1 METAGENOMIC
# 856.2 METAGENOMIC
# 856.3 METAGENOMIC
# 861   METAGENOMIC
# 861.1 METAGENOMIC
# 859   METAGENOMIC
# 859.1 METAGENOMIC
# 860   METAGENOMIC
# 860.1 METAGENOMIC
# 686   METAGENOMIC
# 1455  METAGENOMIC
# 1453  METAGENOMIC
# 1452  METAGENOMIC
# 1451  METAGENOMIC
# 1463  METAGENOMIC
# 843   METAGENOMIC
#       Sample.Attribute
# 3     sample_name: DRS011376 || sample comment: Anode-biofilm in acetate-fed MFC || BioSampleModel: Generic
# 1491  collection_date: 30-Jul-2012 || env_biome: mammalia-associated habitat || env_feature: mammalia-associated habitat || env_material: feces || geo_loc_name: Kenya || host: Papio cynocephalus || lat_lon: 2.717 S 37.1 E || host_age: 10.38 || host_body_product
# 26    Failed to decode
# 26.1  Failed to decode
# 26.2  Failed to decode
# 26.3  Failed to decode
# 774   env_package: MIGS/MIMS/MIMARKS.host-associated || investigation_type: metagenome || biome: Zoo || collection_date: Jun-2009 || feature: Zoo || geo_loc_name: Zoo of Hamburg || lat_lon: 53.596582, 9.938249 || material: feces || host: Elephas maximus indicus
# 688   env_package: MIGS/MIMS/MIMARKS.microbial || investigation_type: metagenome || biome: Tailling pond || collection_date: 2012-07-01 || feature: Suncor Tailings Pond 6 || geo_loc_name: Suncor tailings pond 6 || lat_lon: 57.02, -111.55 || material: waste wate
# 15    None
# 633   env_package: MIGS/MIMS/MIMARKS.wastewater || investigation_type: metagenome || biome: Tailling pond || collection_date: 2011-07-21 || feature: Tailings Pond || geo_loc_name: Syncrude tailings pond, Wood Buffalo, Alberta, Canada || lat_lon: 57.02, -111.55
# 1490  collection_date: 08-Aug-2012 || env_biome: mammalia-associated habitat || env_feature: mammalia-associated habitat || env_material: feces || geo_loc_name: Kenya || host: Papio cynocephalus || lat_lon: 2.717 S 37.1 E || host_age: 7.95 || host_body_product:
# 797   collection_date: 2012-09-23 || env_biome: Tailing Pond || env_feature: Pond || env_material: waste water || geo_loc_name: Canada: North Alberta || lat_lon: 57.02, -111.55 || samp_vol_we_dna_ext: 1000ml || BioSampleModel: MIMS.me || BioSampleModel: MIGS/MI
# 848   collection_date: 2013-04-21 || depth: 0.01m || elev: 250m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Luzhou || lat_lon: 28.88 N 105.45 E || label: Meta-4-2-220-M || BioSampleModel: MIMS.
# 847   collection_date: 2013-04-21 || depth: 0.01m || elev: 250m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Luzhou || lat_lon: 28.88 N 105.45 E || label: Meta-4-1-220-B || BioSampleModel: MIMS.
# 845   collection_date: 2013-04-21 || depth: 0.01m || elev: 250m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Luzhou || lat_lon: 28.88 N 105.45 E || label: Meta-3-2-350-M || BioSampleModel: MIMS.
# 845.1 collection_date: 2013-04-21 || depth: 0.01m || elev: 250m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Luzhou || lat_lon: 28.88 N 105.45 E || label: Meta-3-2-350-M || BioSampleModel: MIMS.
# 845.2 collection_date: 2013-04-21 || depth: 0.01m || elev: 250m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Luzhou || lat_lon: 28.88 N 105.45 E || label: Meta-3-2-350-M || BioSampleModel: MIMS.
# 852   collection_date: 2013-04-21 || depth: 0.01m || elev: 250m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Luzhou || lat_lon: 28.88 N 105.45 E || label: Meta-5-3-140-T || BioSampleModel: MIMS.
# 852.1 collection_date: 2013-04-21 || depth: 0.01m || elev: 250m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Luzhou || lat_lon: 28.88 N 105.45 E || label: Meta-5-3-140-T || BioSampleModel: MIMS.
# 851   collection_date: 2013-04-21 || depth: 0.01m || elev: 250m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Luzhou || lat_lon: 28.88 N 105.45 E || label: Meta-5-2-140-M || BioSampleModel: MIMS.
# 851.1 collection_date: 2013-04-21 || depth: 0.01m || elev: 250m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Luzhou || lat_lon: 28.88 N 105.45 E || label: Meta-5-2-140-M || BioSampleModel: MIMS.
# 851.2 collection_date: 2013-04-21 || depth: 0.01m || elev: 250m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Luzhou || lat_lon: 28.88 N 105.45 E || label: Meta-5-2-140-M || BioSampleModel: MIMS.
# 850   collection_date: 2013-04-21 || depth: 0.01m || elev: 250m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Luzhou || lat_lon: 28.88 N 105.45 E || label: Meta-5-1-140-B || BioSampleModel: MIMS.
# 850.1 collection_date: 2013-04-21 || depth: 0.01m || elev: 250m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Luzhou || lat_lon: 28.88 N 105.45 E || label: Meta-5-1-140-B || BioSampleModel: MIMS.
# 849   collection_date: 2013-04-21 || depth: 0.01m || elev: 250m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Luzhou || lat_lon: 28.88 N 105.45 E || label: Meta-4-3-220-T || BioSampleModel: MIMS.
# 854   collection_date: 2013-04-21 || depth: 0.01m || elev: 250m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Luzhou || lat_lon: 28.88 N 105.45 E || label: Meta-6-2-50-M || BioSampleModel: MIMS.m
# 853   collection_date: 2013-04-21 || depth: 0.01m || elev: 250m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Luzhou || lat_lon: 28.88 N 105.45 E || label: Meta-6-1-50-B || BioSampleModel: MIMS.m
# 853.1 collection_date: 2013-04-21 || depth: 0.01m || elev: 250m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Luzhou || lat_lon: 28.88 N 105.45 E || label: Meta-6-1-50-B || BioSampleModel: MIMS.m
# 853.2 collection_date: 2013-04-21 || depth: 0.01m || elev: 250m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Luzhou || lat_lon: 28.88 N 105.45 E || label: Meta-6-1-50-B || BioSampleModel: MIMS.m
# 840   collection_date: 2013-04-21 || depth: 0.01m || elev: 250m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Luzhou || lat_lon: 28.88 N 105.45 E || label: Meta-1-3-440-T || BioSampleModel: MIMS.
# 840.1 collection_date: 2013-04-21 || depth: 0.01m || elev: 250m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Luzhou || lat_lon: 28.88 N 105.45 E || label: Meta-1-3-440-T || BioSampleModel: MIMS.
# 840.2 collection_date: 2013-04-21 || depth: 0.01m || elev: 250m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Luzhou || lat_lon: 28.88 N 105.45 E || label: Meta-1-3-440-T || BioSampleModel: MIMS.
# 841   collection_date: 2013-04-21 || depth: 0.01m || elev: 250m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Luzhou || lat_lon: 28.88 N 105.45 E || label: Meta-2-1-400-B || BioSampleModel: MIMS.
# 842   collection_date: 2013-04-21 || depth: 0.01m || elev: 250m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Luzhou || lat_lon: 28.88 N 105.45 E || label: Meta-2-2-400-M || BioSampleModel: MIMS.
# 842.1 collection_date: 2013-04-21 || depth: 0.01m || elev: 250m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Luzhou || lat_lon: 28.88 N 105.45 E || label: Meta-2-2-400-M || BioSampleModel: MIMS.
# 838   collection_date: 2013-04-21 || depth: 0.01m || elev: 250m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Luzhou || lat_lon: 28.88 N 105.45 E || label: Meta-1-1-440-B || BioSampleModel: MIMS.
# 838.1 collection_date: 2013-04-21 || depth: 0.01m || elev: 250m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Luzhou || lat_lon: 28.88 N 105.45 E || label: Meta-1-1-440-B || BioSampleModel: MIMS.
# 838.2 collection_date: 2013-04-21 || depth: 0.01m || elev: 250m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Luzhou || lat_lon: 28.88 N 105.45 E || label: Meta-1-1-440-B || BioSampleModel: MIMS.
# 858   collection_date: 2013-05-04 || depth: 0.01m || elev: 400m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Chengdu || lat_lon: 30.65 N 104.06 E || label: Meta-7-3-30-T || BioSampleModel: MIMS.
# 857   collection_date: 2013-05-04 || depth: 0.01m || elev: 400m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Chengdu || lat_lon: 30.65 N 104.06 E || label: Meta-7-2-30-M || BioSampleModel: MIMS.
# 857.1 collection_date: 2013-05-04 || depth: 0.01m || elev: 400m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Chengdu || lat_lon: 30.65 N 104.06 E || label: Meta-7-2-30-M || BioSampleModel: MIMS.
# 855   collection_date: 2013-04-21 || depth: 0.01m || elev: 250m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Luzhou || lat_lon: 28.88 N 105.45 E || label: Meta-6-3-50-T || BioSampleModel: MIMS.m
# 855.1 collection_date: 2013-04-21 || depth: 0.01m || elev: 250m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Luzhou || lat_lon: 28.88 N 105.45 E || label: Meta-6-3-50-T || BioSampleModel: MIMS.m
# 856   collection_date: 2013-05-04 || depth: 0.01m || elev: 400m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Chengdu || lat_lon: 30.65 N 104.06 E || label: Meta-7-1-30-B || BioSampleModel: MIMS.
# 856.1 collection_date: 2013-05-04 || depth: 0.01m || elev: 400m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Chengdu || lat_lon: 30.65 N 104.06 E || label: Meta-7-1-30-B || BioSampleModel: MIMS.
# 856.2 collection_date: 2013-05-04 || depth: 0.01m || elev: 400m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Chengdu || lat_lon: 30.65 N 104.06 E || label: Meta-7-1-30-B || BioSampleModel: MIMS.
# 856.3 collection_date: 2013-05-04 || depth: 0.01m || elev: 400m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Chengdu || lat_lon: 30.65 N 104.06 E || label: Meta-7-1-30-B || BioSampleModel: MIMS.
# 861   collection_date: 2013-04-25 || depth: 0.01m || elev: 500m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Mianyang || lat_lon: 31.46 N 104.68 E || label: Meta-8-3-20-T || BioSampleModel: MIMS
# 861.1 collection_date: 2013-04-25 || depth: 0.01m || elev: 500m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Mianyang || lat_lon: 31.46 N 104.68 E || label: Meta-8-3-20-T || BioSampleModel: MIMS
# 859   collection_date: 2013-04-25 || depth: 0.01m || elev: 500m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Mianyang || lat_lon: 31.46 N 104.68 E || label: Meta-8-1-20-B || BioSampleModel: MIMS
# 859.1 collection_date: 2013-04-25 || depth: 0.01m || elev: 500m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Mianyang || lat_lon: 31.46 N 104.68 E || label: Meta-8-1-20-B || BioSampleModel: MIMS
# 860   collection_date: 2013-04-25 || depth: 0.01m || elev: 500m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Mianyang || lat_lon: 31.46 N 104.68 E || label: Meta-8-2-20-M || BioSampleModel: MIMS
# 860.1 collection_date: 2013-04-25 || depth: 0.01m || elev: 500m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Mianyang || lat_lon: 31.46 N 104.68 E || label: Meta-8-2-20-M || BioSampleModel: MIMS
# 686   env_package: MIGS/MIMS/MIMARKS.wastewater || investigation_type: metagenome || biome: Tailling pond || collection_date: 2011-07-21 || feature: Tailings Pond || geo_loc_name: Syncrude tailings pond, Wood Buffalo, Alberta, Canada || lat_lon: 40.1, -104.8 ||
# 1455  collection_date: 07-Jul-2012 || env_biome: mammalia-associated habitat || env_feature: mammalia-associated habitat || env_material: feces || geo_loc_name: Kenya || host: Papio cynocephalus || lat_lon: 2.717 S 37.1 E || host_age: 8.26 || host_body_product:
# 1453  collection_date: 06-Aug-2012 || env_biome: mammalia-associated habitat || env_feature: mammalia-associated habitat || env_material: feces || geo_loc_name: Kenya || host: Papio cynocephalus || lat_lon: 2.717 S 37.1 E || host_age: 12.85 || host_body_product
# 1452  collection_date: 06-Aug-2012 || env_biome: mammalia-associated habitat || env_feature: mammalia-associated habitat || env_material: feces || geo_loc_name: Kenya || host: Papio cynocephalus || lat_lon: 2.717 S 37.1 E || host_age: 8.69 || host_body_product:
# 1451  collection_date: 27-Jul-2012 || env_biome: mammalia-associated habitat || env_feature: mammalia-associated habitat || env_material: feces || geo_loc_name: Kenya || host: Papio cynocephalus || lat_lon: 2.717 S 37.1 E || host_age: 13.27 || host_body_product
# 1463  collection_date: 19-Jul-2012 || env_biome: mammalia-associated habitat || env_feature: mammalia-associated habitat || env_material: feces || geo_loc_name: Kenya || host: Papio cynocephalus || lat_lon: 2.717 S 37.1 E || host_age: 10.61 || host_body_product
# 843   collection_date: 2013-04-21 || depth: 0.01m || elev: 250m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Luzhou || lat_lon: 28.88 N 105.45 E || label: Meta-2-3-400-T || BioSampleModel: MIMS.
#       Study.Accession
# 3     DRP001053
# 1491  SRP051834
# 26    ERP002363
# 26.1  ERP002363
# 26.2  ERP002363
# 26.3  ERP002363
# 774   SRP040073
# 688   SRP017582
# 15    ERP012237
# 633   SRP017582
# 1490  SRP051834
# 797   SRP017582
# 848   SRP046072
# 847   SRP046072
# 845   SRP046072
# 845.1 SRP046072
# 845.2 SRP046072
# 852   SRP046072
# 852.1 SRP046072
# 851   SRP046072
# 851.1 SRP046072
# 851.2 SRP046072
# 850   SRP046072
# 850.1 SRP046072
# 849   SRP046072
# 854   SRP046072
# 853   SRP046072
# 853.1 SRP046072
# 853.2 SRP046072
# 840   SRP046072
# 840.1 SRP046072
# 840.2 SRP046072
# 841   SRP046072
# 842   SRP046072
# 842.1 SRP046072
# 838   SRP046072
# 838.1 SRP046072
# 838.2 SRP046072
# 858   SRP046072
# 857   SRP046072
# 857.1 SRP046072
# 855   SRP046072
# 855.1 SRP046072
# 856   SRP046072
# 856.1 SRP046072
# 856.2 SRP046072
# 856.3 SRP046072
# 861   SRP046072
# 861.1 SRP046072
# 859   SRP046072
# 859.1 SRP046072
# 860   SRP046072
# 860.1 SRP046072
# 686   SRP017582
# 1455  SRP051834
# 1453  SRP051834
# 1452  SRP051834
# 1451  SRP051834
# 1463  SRP051834
# 843   SRP046072
#       Study.Title
# 3     Comparative metagenome analyses of anode-associated microbial communities developed in rice paddy field-soil microbial fuel cells
# 1491  Baboon feces Metagenome
# 26    Metagenomic study of the microbial genes abundance in treated palm oil mill effluent
# 26.1  Metagenomic study of the microbial genes abundance in treated palm oil mill effluent
# 26.2  Metagenomic study of the microbial genes abundance in treated palm oil mill effluent
# 26.3  Metagenomic study of the microbial genes abundance in treated palm oil mill effluent
# 774   Elephant feces Metagenome
# 688   Hydrocarbon Metagenome
# 15    The Illumina HiSeq 2000 platform was used to sequence two metagenomes from two Danish biogas plants.
# 633   Hydrocarbon Metagenome
# 1490  Baboon feces Metagenome
# 797   Hydrocarbon Metagenome
# 848   Pit mud of Chinese liqour fermentation reactorMetagenome
# 847   Pit mud of Chinese liqour fermentation reactorMetagenome
# 845   Pit mud of Chinese liqour fermentation reactorMetagenome
# 845.1 Pit mud of Chinese liqour fermentation reactorMetagenome
# 845.2 Pit mud of Chinese liqour fermentation reactorMetagenome
# 852   Pit mud of Chinese liqour fermentation reactorMetagenome
# 852.1 Pit mud of Chinese liqour fermentation reactorMetagenome
# 851   Pit mud of Chinese liqour fermentation reactorMetagenome
# 851.1 Pit mud of Chinese liqour fermentation reactorMetagenome
# 851.2 Pit mud of Chinese liqour fermentation reactorMetagenome
# 850   Pit mud of Chinese liqour fermentation reactorMetagenome
# 850.1 Pit mud of Chinese liqour fermentation reactorMetagenome
# 849   Pit mud of Chinese liqour fermentation reactorMetagenome
# 854   Pit mud of Chinese liqour fermentation reactorMetagenome
# 853   Pit mud of Chinese liqour fermentation reactorMetagenome
# 853.1 Pit mud of Chinese liqour fermentation reactorMetagenome
# 853.2 Pit mud of Chinese liqour fermentation reactorMetagenome
# 840   Pit mud of Chinese liqour fermentation reactorMetagenome
# 840.1 Pit mud of Chinese liqour fermentation reactorMetagenome
# 840.2 Pit mud of Chinese liqour fermentation reactorMetagenome
# 841   Pit mud of Chinese liqour fermentation reactorMetagenome
# 842   Pit mud of Chinese liqour fermentation reactorMetagenome
# 842.1 Pit mud of Chinese liqour fermentation reactorMetagenome
# 838   Pit mud of Chinese liqour fermentation reactorMetagenome
# 838.1 Pit mud of Chinese liqour fermentation reactorMetagenome
# 838.2 Pit mud of Chinese liqour fermentation reactorMetagenome
# 858   Pit mud of Chinese liqour fermentation reactorMetagenome
# 857   Pit mud of Chinese liqour fermentation reactorMetagenome
# 857.1 Pit mud of Chinese liqour fermentation reactorMetagenome
# 855   Pit mud of Chinese liqour fermentation reactorMetagenome
# 855.1 Pit mud of Chinese liqour fermentation reactorMetagenome
# 856   Pit mud of Chinese liqour fermentation reactorMetagenome
# 856.1 Pit mud of Chinese liqour fermentation reactorMetagenome
# 856.2 Pit mud of Chinese liqour fermentation reactorMetagenome
# 856.3 Pit mud of Chinese liqour fermentation reactorMetagenome
# 861   Pit mud of Chinese liqour fermentation reactorMetagenome
# 861.1 Pit mud of Chinese liqour fermentation reactorMetagenome
# 859   Pit mud of Chinese liqour fermentation reactorMetagenome
# 859.1 Pit mud of Chinese liqour fermentation reactorMetagenome
# 860   Pit mud of Chinese liqour fermentation reactorMetagenome
# 860.1 Pit mud of Chinese liqour fermentation reactorMetagenome
# 686   Hydrocarbon Metagenome
# 1455  Baboon feces Metagenome
# 1453  Baboon feces Metagenome
# 1452  Baboon feces Metagenome
# 1451  Baboon feces Metagenome
# 1463  Baboon feces Metagenome
# 843   Pit mud of Chinese liqour fermentation reactorMetagenome
#       UBA
# 3     UBA6
# 1491  UBA48
# 26    UBA71
# 26.1  UBA72
# 26.2  UBA75
# 26.3  UBA78
# 774   UBA113
# 688   UBA147
# 15    UBA238
# 633   UBA248
# 1490  UBA271
# 797   UBA280
# 848   UBA292
# 847   UBA296
# 845   UBA306
# 845.1 UBA308
# 845.2 UBA309
# 852   UBA314
# 852.1 UBA315
# 851   UBA317
# 851.1 UBA319
# 851.2 UBA321
# 850   UBA328
# 850.1 UBA329
# 849   UBA333
# 854   UBA335
# 853   UBA343
# 853.1 UBA344
# 853.2 UBA345
# 840   UBA358
# 840.1 UBA359
# 840.2 UBA360
# 841   UBA364
# 842   UBA370
# 842.1 UBA371
# 838   UBA378
# 838.1 UBA381
# 838.2 UBA382
# 858   UBA386
# 857   UBA393
# 857.1 UBA394
# 855   UBA399
# 855.1 UBA400
# 856   UBA404
# 856.1 UBA407
# 856.2 UBA408
# 856.3 UBA409
# 861   UBA414
# 861.1 UBA415
# 859   UBA421
# 859.1 UBA422
# 860   UBA427
# 860.1 UBA429
# 686   UBA472
# 1455  UBA480
# 1453  UBA481
# 1452  UBA482
# 1451  UBA483
# 1463  UBA537
# 843   UBA593

# %%
# Match table with species name with source of genome
UBA_source = UBA_source[match(UBA_table$UBA, UBA_source$UBA),]
UBA_source$name = UBA_table$name
UBA_positions = match(UBA_source$name, rownames(methanomassilii_data))

# Add source data to methanomasilii table
for(pos in (1:length(UBA_positions))){
    position = UBA_positions[pos]
    methanomassilii_data$source_1[position] = as.character(UBA_source$Sample.Attribute[pos]) 
    methanomassilii_data$source_2[position] = as.character(UBA_source$Study.Title[pos])  
}

# %%
methanomassilii_data %>% head(., n = 15)
# Out:
#                                                           Assembly
# Methanomassiliicoccus_luminyensis_B10                     GCA_000308215
# Candidatus_Methanomethylophilus_alvus_Mx1201              GCA_000300255
# Candidatus_Methanomassiliicoccus_intestinalis_Issoire_Mx1 GCA_000404225
# Candidatus_Methanoplasma_termitum                         GCA_000800805
# Candidatus_Methanomethylophilus_sp_1R26                   GCA_001481295
# Methanomassiliicoccales_archaeon_RumEn_M2                 GCA_001421175
# Methanomassiliicoccales_archaeon_RumEn_M1                 GCA_001421185
# uncultured_Candidatus_Methanomethylophilus_sp_RUG779      GCA_900313075
# uncultured_Candidatus_Methanomethylophilus_sp_hRUG898     GCA_900314325
# Methanomassiliicoccaceae_archaeon_UBA409                  GCA_002494585
# Methanomassiliicoccus_sp_UBA238                           GCA_002494705
# Methanomassiliicoccaceae_archaeon_UBA482                  GCA_002494805
# Methanomassiliicoccaceae_archaeon_UBA593                  GCA_002495325
# Methanomassiliicoccaceae_archaeon_UBA394                  GCA_002495495
# Methanomassiliicoccus_sp_UBA292                           GCA_002495585
#                                                           GC        Len
# Methanomassiliicoccus_luminyensis_B10                     0.6047886 2620233
# Candidatus_Methanomethylophilus_alvus_Mx1201              0.5559482 1666795
# Candidatus_Methanomassiliicoccus_intestinalis_Issoire_Mx1 0.4125543 1931651
# Candidatus_Methanoplasma_termitum                         0.4920570 1488669
# Candidatus_Methanomethylophilus_sp_1R26                   0.6039454 1723106
# Methanomassiliicoccales_archaeon_RumEn_M2                 0.5460069 1280797
# Methanomassiliicoccales_archaeon_RumEn_M1                 0.6209410 2121026
# uncultured_Candidatus_Methanomethylophilus_sp_RUG779      0.6168057 1262884
# uncultured_Candidatus_Methanomethylophilus_sp_hRUG898     0.6102892 1388681
# Methanomassiliicoccaceae_archaeon_UBA409                  0.5576718 1292133
# Methanomassiliicoccus_sp_UBA238                           0.5897788 1711594
# Methanomassiliicoccaceae_archaeon_UBA482                  0.5748514 1648656
# Methanomassiliicoccaceae_archaeon_UBA593                  0.5812618 1496212
# Methanomassiliicoccaceae_archaeon_UBA394                  0.5640276 1063745
# Methanomassiliicoccus_sp_UBA292                           0.6038551 2130235
#                                                           Genes
# Methanomassiliicoccus_luminyensis_B10                     2607
# Candidatus_Methanomethylophilus_alvus_Mx1201              1636
# Candidatus_Methanomassiliicoccus_intestinalis_Issoire_Mx1 1855
# Candidatus_Methanoplasma_termitum                         1419
# Candidatus_Methanomethylophilus_sp_1R26                   2079
# Methanomassiliicoccales_archaeon_RumEn_M2                 1497
# Methanomassiliicoccales_archaeon_RumEn_M1                 2515
# uncultured_Candidatus_Methanomethylophilus_sp_RUG779      1374
# uncultured_Candidatus_Methanomethylophilus_sp_hRUG898     1421
# Methanomassiliicoccaceae_archaeon_UBA409                  1369
# Methanomassiliicoccus_sp_UBA238                           1799
# Methanomassiliicoccaceae_archaeon_UBA482                  1564
# Methanomassiliicoccaceae_archaeon_UBA593                  1479
# Methanomassiliicoccaceae_archaeon_UBA394                  1152
# Methanomassiliicoccus_sp_UBA292                           2205
#                                                           source_1
# Methanomassiliicoccus_luminyensis_B10                     NA
# Candidatus_Methanomethylophilus_alvus_Mx1201              NA
# Candidatus_Methanomassiliicoccus_intestinalis_Issoire_Mx1 NA
# Candidatus_Methanoplasma_termitum                         NA
# Candidatus_Methanomethylophilus_sp_1R26                   NA
# Methanomassiliicoccales_archaeon_RumEn_M2                 NA
# Methanomassiliicoccales_archaeon_RumEn_M1                 NA
# uncultured_Candidatus_Methanomethylophilus_sp_RUG779      NA
# uncultured_Candidatus_Methanomethylophilus_sp_hRUG898     NA
# Methanomassiliicoccaceae_archaeon_UBA409                  collection_date: 2013-05-04 || depth: 0.01m || elev: 400m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Chengdu || lat_lon: 30.65 N 104.06 E || label: Meta-7-1-30-B || BioSampleModel: MIMS.
# Methanomassiliicoccus_sp_UBA238                           None
# Methanomassiliicoccaceae_archaeon_UBA482                  collection_date: 06-Aug-2012 || env_biome: mammalia-associated habitat || env_feature: mammalia-associated habitat || env_material: feces || geo_loc_name: Kenya || host: Papio cynocephalus || lat_lon: 2.717 S 37.1 E || host_age: 8.69 || host_body_product:
# Methanomassiliicoccaceae_archaeon_UBA593                  collection_date: 2013-04-21 || depth: 0.01m || elev: 250m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Luzhou || lat_lon: 28.88 N 105.45 E || label: Meta-2-3-400-T || BioSampleModel: MIMS.
# Methanomassiliicoccaceae_archaeon_UBA394                  collection_date: 2013-05-04 || depth: 0.01m || elev: 400m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Chengdu || lat_lon: 30.65 N 104.06 E || label: Meta-7-2-30-M || BioSampleModel: MIMS.
# Methanomassiliicoccus_sp_UBA292                           collection_date: 2013-04-21 || depth: 0.01m || elev: 250m || env_biome: anthropogenic terrestrial biome || env_feature: soil || env_material: mud || geo_loc_name: China: Luzhou || lat_lon: 28.88 N 105.45 E || label: Meta-4-2-220-M || BioSampleModel: MIMS.
#                                                           source_2
# Methanomassiliicoccus_luminyensis_B10                     NA
# Candidatus_Methanomethylophilus_alvus_Mx1201              NA
# Candidatus_Methanomassiliicoccus_intestinalis_Issoire_Mx1 NA
# Candidatus_Methanoplasma_termitum                         NA
# Candidatus_Methanomethylophilus_sp_1R26                   NA
# Methanomassiliicoccales_archaeon_RumEn_M2                 NA
# Methanomassiliicoccales_archaeon_RumEn_M1                 NA
# uncultured_Candidatus_Methanomethylophilus_sp_RUG779      NA
# uncultured_Candidatus_Methanomethylophilus_sp_hRUG898     NA
# Methanomassiliicoccaceae_archaeon_UBA409                  Pit mud of Chinese liqour fermentation reactorMetagenome
# Methanomassiliicoccus_sp_UBA238                           The Illumina HiSeq 2000 platform was used to sequence two metagenomes from two Danish biogas plants.
# Methanomassiliicoccaceae_archaeon_UBA482                  Baboon feces Metagenome
# Methanomassiliicoccaceae_archaeon_UBA593                  Pit mud of Chinese liqour fermentation reactorMetagenome
# Methanomassiliicoccaceae_archaeon_UBA394                  Pit mud of Chinese liqour fermentation reactorMetagenome
# Methanomassiliicoccus_sp_UBA292                           Pit mud of Chinese liqour fermentation reactorMetagenome
#                                                           location
# Methanomassiliicoccus_luminyensis_B10                     NA
# Candidatus_Methanomethylophilus_alvus_Mx1201              NA
# Candidatus_Methanomassiliicoccus_intestinalis_Issoire_Mx1 NA
# Candidatus_Methanoplasma_termitum                         NA
# Candidatus_Methanomethylophilus_sp_1R26                   NA
# Methanomassiliicoccales_archaeon_RumEn_M2                 NA
# Methanomassiliicoccales_archaeon_RumEn_M1                 NA
# uncultured_Candidatus_Methanomethylophilus_sp_RUG779      NA
# uncultured_Candidatus_Methanomethylophilus_sp_hRUG898     NA
# Methanomassiliicoccaceae_archaeon_UBA409                  NA
# Methanomassiliicoccus_sp_UBA238                           NA
# Methanomassiliicoccaceae_archaeon_UBA482                  NA
# Methanomassiliicoccaceae_archaeon_UBA593                  NA
# Methanomassiliicoccaceae_archaeon_UBA394                  NA
# Methanomassiliicoccus_sp_UBA292                           NA

# %%
raw_metadata = file.path(metadata_folder, "assemblies_metadata_raw.txt")
write.table(methanomassilii_data, raw_metadata, sep = "\t", dec = ".", quote = F)

# %% [markdown]
# ### Other genomes
# The final format of the metadata table, as well as the information of the remaining genomes will be organized manually

# %%
UBA_source[UBA_source$UBA == "UBA6",]
# Out:
#   SRA.Experiment.Accession
# 3 DRX011531
#   Experiment.Title
# 3 High-throughput sequencing of the metagenome extracted from AM-anode biofilm
#   Library.Source
# 3 METAGENOMIC
#   Sample.Attribute
# 3 sample_name: DRS011376 || sample comment: Anode-biofilm in acetate-fed MFC || BioSampleModel: Generic
#   Study.Accession
# 3 DRP001053
#   Study.Title
# 3 Comparative metagenome analyses of anode-associated microbial communities developed in rice paddy field-soil microbial fuel cells
#   UBA  name
# 3 UBA6 Methanomassiliicoccus_sp_UBA6
