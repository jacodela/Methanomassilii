# %% [markdown]
# # Goal
# Jacobo de la Cuesta-Zuluaga.
#
# Now that I classified taxonomically the **vadinCA11** bin as member of the *Methanomassiliicoccales* order, and that I established that the bin can be considered as a near complete genome with low contamination (98.4% and 0%, respectively), I can download the genomes of closely related organisms to perform the comparative genomic analyses. In this notebook I will fetch the assemblies from NCBI and assess their quality.

# %% [markdown]
# # Init

# %%
import os
import pandas as pd
import subprocess
import urllib.request
import re

# %% [markdown]
# # Var

# %%
# Work dir
work_dir = "/ebio/abt3_projects/vadinCA11/data/V11"

# Included genomes dir
included_genomes_dir = os.path.join(work_dir, "included_genomes")

# vadinCA11 genome bin
V11_bin = "/ebio/abt3_projects/vadinCA11/data/metagenome/LLMGA/HiSeqRun83-91/bin_refine/DAS_Tool//bins_DASTool_bins/metabat2_low_PE.478.contigs.fa"
V11_folder = "/ebio/abt3_projects/vadinCA11/data/metagenome/LLMGA/HiSeqRun83-91/bin_refine/DAS_Tool//bins_DASTool_bins/"

# Misc
quality_env = "py2_genome_quality"
metacompass_env = "metacompass"

# %% [markdown]
# # Get genomes
# I wasn't able to make `ncbi-genome-download` work to get the genomes of all available *Methanomassiliicoccales*. Therefore, I will adapt and use Guillermo's script, which I know works and have already used.

# %%
# Get the list of assemblies into the file `assembly_summary.txt`
# In case of needing only bacterial genes, change FTP adress for
# ftp://ftp.ncbi.nlm.nih.gov/genomes/genbank/bacteria/assembly_summary.txt"
assembly_summary = os.path.join(work_dir, "genomes", "assembly_summary.txt")
ncbi_ftp = "ftp://ftp.ncbi.nlm.nih.gov/genomes/genbank/assembly_summary_genbank.txt"
urllib.request.urlretrieve(ncbi_ftp, assembly_summary)

# Read the file skipping the first line
data_ncbi = pd.read_csv(assembly_summary, sep='\t', skiprows=1);

# Define a simple dataset of the complete genomes only, including the URLs where we can download them.
# complete_genes = data_ncbi[data_ncbi["assembly_level"] == "Complete Genome"][["# assembly_accession", 
#                                                                              "asm_name", "organism_name", 
#                                                                              "ftp_path"]]


# Define a simple dataset of all genomes and assemblies, including the URLs where we can download them.
complete_genes = data_ncbi[["# assembly_accession", "asm_name", "organism_name", "ftp_path"]]

complete_genes.head()
# Out:
#   # assembly_accession                asm_name            organism_name  \
# 0      GCA_000001215.4  Release 6 plus ISO1 MT  Drosophila melanogaster
# 1     GCA_000001405.27              GRCh38.p12             Homo sapiens
# 2      GCA_000001515.5             Pan_tro 3.0          Pan troglodytes
# 3      GCA_000001545.3        P_pygmaeus_2.0.2             Pongo abelii
# 4      GCA_000001635.8               GRCm38.p6             Mus musculus
#
#                                             ftp_path
# 0  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 1  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 3  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 4  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...

# %%
from Bio import SeqIO
import os


def get_members(accession_list, directory, output_file):
    os.chdir(directory)
    assembly_lst = []
    accession_lst = []
    organism_lst = []
    length_lst = []
    
    for accession in accession_list:
        _df = complete_genes[complete_genes["# assembly_accession"] == accession]
        
        if _df.shape[0] != 1:
            continue
        
        url_dir = _df["ftp_path"].iloc[0]
        asm_name = _df["asm_name"].iloc[0]
        filename = "{}_{}_genomic.fna.gz".format(accession, asm_name)
        
        if not os.path.isfile(filename):
            url_lnk = "{}/{}".format(url_dir, filename)
            #urllib.request.urlretrieve(url_lnk, filename)
            urllib.request.urlretrieve("{}/{}_genomic.fna.gz".format(url_dir, url_dir.split("/")[-1]), filename)
        
        assembly_lst.append(asm_name)
        accession_lst.append(accession)
        organism_lst.append(_df["organism_name"].iloc[0])
        
    _df = pd.DataFrame({"Assembly": assembly_lst, 
                        "Organism": organism_lst, 
                        "Accession": accession_lst})
    _df.to_csv("%s" % output_file)
    
    return(_df)

# %%
# Looked for all assemblies available for Methanomassiliicoccales[ORGANISM] in NCBI assembly
# on 07.06.2018
download_folder = os.path.join(work_dir, "genomes")
downloaded_list = os.path.join(download_folder, "Methanomassiliicoccales.csv")
Methanomassiliicoccales_members = ["GCA_000308215.1", "GCA_000300255.2", "GCA_000404225.1", 
                                   "GCA_000800805.1", "GCA_001481295.1", "GCA_001421175.1", 
                                   "GCA_001421185.1", "GCA_900313075.1", "GCA_900314325.1", 
                                   "GCA_002494585.1", "GCA_002494705.1", "GCA_002494805.1", 
                                   "GCA_002494945.1", "GCA_002495125.1", "GCA_002495325.1", 
                                   "GCA_002495495.1", "GCA_002495585.1", "GCA_002495665.1", 
                                   "GCA_002496345.1", "GCA_002496385.1", "GCA_002496785.1", 
                                   "GCA_002496945.1", "GCA_002497075.1", "GCA_002497155.1", 
                                   "GCA_002497195.1", "GCA_002497475.1", "GCA_002497815.1", 
                                   "GCA_002497995.1", "GCA_002498285.1", "GCA_002498365.1", 
                                   "GCA_002498425.1", "GCA_002498545.1", "GCA_002498605.1", 
                                   "GCA_002498765.1", "GCA_002498785.1", "GCA_002498805.1", 
                                   "GCA_002499085.1", "GCA_002502005.1", "GCA_002502165.1", 
                                   "GCA_002502465.1", "GCA_002502545.1", "GCA_002502765.1", 
                                   "GCA_002502925.1", "GCA_002502965.1", "GCA_002503495.1", 
                                   "GCA_002503545.1", "GCA_002503645.1", "GCA_002503785.1", 
                                   "GCA_002503925.1", "GCA_002504405.1", "GCA_002504495.1", 
                                   "GCA_002504525.1", "GCA_002504645.1", "GCA_002505225.1", 
                                   "GCA_002505245.1", "GCA_002505275.1", "GCA_002505345.1", 
                                   "GCA_002505735.1", "GCA_002506175.1", "GCA_002506255.1", 
                                   "GCA_002506325.1", "GCA_002506425.1", "GCA_002506565.1", 
                                   "GCA_002506865.1", "GCA_002506905.1", "GCA_002506985.1", 
                                   "GCA_002506995.1", "GCA_002508545.1", "GCA_002508555.1", 
                                   "GCA_002508585.1", "GCA_002508595.1", "GCA_002508625.1", 
                                   "GCA_002509405.1", "GCA_002509415.1", "GCA_002509425.1", 
                                   "GCA_002509465.1", "GCA_003135935.1", "GCA_003153895.1"]

# %%
# Download genome assemblies in fasta format from NCBI
Methanomassiliicoccales = get_members(Methanomassiliicoccales_members, 
                                      download_folder, 
                                      downloaded_list)

# %%
# Uncompress genome files
gunzip_job = "gunzip {0}/*.fna.gz".format(genomes_folder)
print(gunzip_job)
# !$gunzip_job
# Out:
# gunzip /ebio/abt3_projects/vadinCA11/data/V11/genomes/*.fna.gz

# %%
# Rename all files just to have the accession in the name
rename_job = "cd {0}; rename 's/_[a-zA-Z].*_genomic//g' GCA*".format(download_folder)
print(rename_job)
# !$rename_job
# Out:
# cd /ebio/abt3_projects/vadinCA11/data/V11/genomes; rename 's/_[a-zA-Z].*_genomic//g' GCA*

# %%
# Fix a couple of errors in the name of the files
# !pwd
# !mv GCA_003135935.1_20110800.fna GCA_003135935.1.fna
# !mv GCA_003153895.1_20120700.fna GCA_003153895.1.fna
# Out:
# /ebio/abt3_projects/vadinCA11/data/V11/genomes

# %%
# Print table with accessions
Methanomassiliicoccales_df = pd.read_csv(downloaded_list, sep=',', header=0)
Methanomassiliicoccales_df = Methanomassiliicoccales_df.drop(["Unnamed: 0"], axis=1)
Methanomassiliicoccales_df
# Out:
#           Accession                         Assembly  \
# 0   GCA_000308215.1                       ASM30821v1
# 1   GCA_000300255.2                       ASM30025v2
# 2   GCA_000404225.1                       ASM40422v1
# 3   GCA_000800805.1                       ASM80080v1
# 4   GCA_001481295.1                      ASM148129v1
# 5   GCA_001421175.1                      ASM142117v1
# 6   GCA_001421185.1                      ASM142118v1
# 7   GCA_900313075.1   Rumen uncultured genome RUG779
# 8   GCA_900314325.1  Rumen uncultured genome hRUG898
# 9   GCA_002494585.1                      ASM249458v1
# 10  GCA_002494705.1                      ASM249470v1
# 11  GCA_002494805.1                      ASM249480v1
# 12  GCA_002494945.1                      ASM249494v1
# 13  GCA_002495125.1                      ASM249512v1
# 14  GCA_002495325.1                      ASM249532v1
# 15  GCA_002495495.1                      ASM249549v1
# 16  GCA_002495585.1                      ASM249558v1
# 17  GCA_002495665.1                      ASM249566v1
# 18  GCA_002496345.1                      ASM249634v1
# 19  GCA_002496385.1                      ASM249638v1
# 20  GCA_002496785.1                      ASM249678v1
# 21  GCA_002496945.1                      ASM249694v1
# 22  GCA_002497075.1                      ASM249707v1
# 23  GCA_002497155.1                      ASM249715v1
# 24  GCA_002497195.1                      ASM249719v1
# 25  GCA_002497475.1                      ASM249747v1
# 26  GCA_002497815.1                      ASM249781v1
# 27  GCA_002497995.1                      ASM249799v1
# 28  GCA_002498285.1                      ASM249828v1
# 29  GCA_002498365.1                      ASM249836v1
# ..              ...                              ...
# 48  GCA_002503925.1                      ASM250392v1
# 49  GCA_002504405.1                      ASM250440v1
# 50  GCA_002504495.1                      ASM250449v1
# 51  GCA_002504525.1                      ASM250452v1
# 52  GCA_002504645.1                      ASM250464v1
# 53  GCA_002505225.1                      ASM250522v1
# 54  GCA_002505245.1                      ASM250524v1
# 55  GCA_002505275.1                      ASM250527v1
# 56  GCA_002505345.1                      ASM250534v1
# 57  GCA_002505735.1                      ASM250573v1
# 58  GCA_002506175.1                      ASM250617v1
# 59  GCA_002506255.1                      ASM250625v1
# 60  GCA_002506325.1                      ASM250632v1
# 61  GCA_002506425.1                      ASM250642v1
# 62  GCA_002506565.1                      ASM250656v1
# 63  GCA_002506865.1                      ASM250686v1
# 64  GCA_002506905.1                      ASM250690v1
# 65  GCA_002506985.1                      ASM250698v1
# 66  GCA_002506995.1                      ASM250699v1
# 67  GCA_002508545.1                      ASM250854v1
# 68  GCA_002508555.1                      ASM250855v1
# 69  GCA_002508585.1                      ASM250858v1
# 70  GCA_002508595.1                      ASM250859v1
# 71  GCA_002508625.1                      ASM250862v1
# 72  GCA_002509405.1                      ASM250940v1
# 73  GCA_002509415.1                      ASM250941v1
# 74  GCA_002509425.1                      ASM250942v1
# 75  GCA_002509465.1                      ASM250946v1
# 76  GCA_003135935.1                     20110800_E3D
# 77  GCA_003153895.1                     20120700_E3M
#
#                                              Organism
# 0               Methanomassiliicoccus luminyensis B10
# 1        Candidatus Methanomethylophilus alvus Mx1201
# 2   Candidatus Methanomassiliicoccus intestinalis ...
# 3                   Candidatus Methanoplasma termitum
# 4            Candidatus Methanomethylophilus sp. 1R26
# 5           Methanomassiliicoccales archaeon RumEn M2
# 6           Methanomassiliicoccales archaeon RumEn M1
# 7      uncultured Candidatus Methanomethylophilus sp.
# 8      uncultured Candidatus Methanomethylophilus sp.
# 9            Methanomassiliicoccaceae archaeon UBA409
# 10                   Methanomassiliicoccus sp. UBA238
# 11           Methanomassiliicoccaceae archaeon UBA482
# 12           Methanomassiliicoccaceae archaeon UBA396
# 13           Methanomassiliicoccaceae archaeon UBA387
# 14           Methanomassiliicoccaceae archaeon UBA593
# 15           Methanomassiliicoccaceae archaeon UBA394
# 16                   Methanomassiliicoccus sp. UBA292
# 17           Methanomassiliicoccaceae archaeon UBA378
# 18                   Methanomassiliicoccus sp. UBA382
# 19            Methanomassiliicoccales archaeon UBA147
# 20           Methanomassiliicoccaceae archaeon UBA407
# 21           Methanomassiliicoccaceae archaeon UBA408
# 22           Methanomassiliicoccaceae archaeon UBA472
# 23           Methanomassiliicoccaceae archaeon UBA309
# 24           Methanomassiliicoccaceae archaeon UBA354
# 25           Methanomassiliicoccaceae archaeon UBA483
# 26            Methanomassiliicoccales archaeon UBA149
# 27                   Methanomassiliicoccus sp. UBA393
# 28                   Methanomassiliicoccus sp. UBA386
# 29           Methanomassiliicoccaceae archaeon UBA421
# ..                                                ...
# 48           Methanomassiliicoccaceae archaeon UBA481
# 49            Methanomassiliicoccaceae archaeon UBA71
# 50           Methanomassiliicoccaceae archaeon UBA537
# 51                   Methanomassiliicoccus sp. UBA345
# 52           Methanomassiliicoccaceae archaeon UBA306
# 53                   Methanomassiliicoccus sp. UBA429
# 54           Methanomassiliicoccaceae archaeon UBA422
# 55           Methanomassiliicoccaceae archaeon UBA371
# 56           Methanomassiliicoccaceae archaeon UBA370
# 57           Methanomassiliicoccaceae archaeon UBA298
# 58           Methanomassiliicoccaceae archaeon UBA113
# 59           Methanomassiliicoccaceae archaeon UBA367
# 60           Methanomassiliicoccaceae archaeon UBA314
# 61           Methanomassiliicoccaceae archaeon UBA480
# 62           Methanomassiliicoccaceae archaeon UBA333
# 63           Methanomassiliicoccaceae archaeon UBA329
# 64           Methanomassiliicoccaceae archaeon UBA328
# 65           Methanomassiliicoccaceae archaeon UBA248
# 66           Methanomassiliicoccaceae archaeon UBA427
# 67                     Methanomassiliicoccus sp. UBA6
# 68                   Methanomassiliicoccus sp. UBA364
# 69                   Methanomassiliicoccus sp. UBA360
# 70            Methanomassiliicoccaceae archaeon UBA48
# 71           Methanomassiliicoccaceae archaeon UBA344
# 72            Methanomassiliicoccaceae archaeon UBA72
# 73           Methanomassiliicoccaceae archaeon UBA319
# 74           Methanomassiliicoccaceae archaeon UBA359
# 75           Methanomassiliicoccaceae archaeon UBA308
# 76                  Methanomassiliicoccaceae archaeon
# 77                  Methanomassiliicoccaceae archaeon
#
# [78 rows x 3 columns]

# %%
# Write file downloaded genomes names and accessions
include_table = os.path.join(download_folder, "included_table.txt")
Methanomassiliicoccales_df.to_csv(include_table, sep='\t')

# %% [markdown]
# # Assess quality of downloaded genomes
# To guarantee that the downstream analyses are correct, I will first perform a quality assessment of the downloaded genomes using CheckM. This way, I can identify and exclude incomplete or contaminated genomes.

# %% [markdown]
# ## Run CheckM

# %%
# Running CheckM to verify the completness and redundancy of the downloaded genomes
#

checkm_file = os.path.join(work_dir, "checkm_downloaded_genomes", 'CheckM_genomes.txt')
checkm_cmd = """checkm lineage_wf -t {0} \
    -x {1} \
    -f {2} \
    {3} {4}/checkm_downloaded_genomes """
checkm_cmd = checkm_cmd.format(8, "fna", checkm_file, download_folder, work_dir)
checkm_job = 'bash -c "source activate {0}; {1}"'
checkm_job = checkm_job.format(quality_env, checkm_cmd)
print(checkm_job)
# !$checkm_job
# Out:
# bash -c "source activate py2_genome_quality; checkm lineage_wf -t 8     -x fna     -f /ebio/abt3_projects/vadinCA11/data/V11/checkm_downloaded_genomes/CheckM_genomes.txt     /ebio/abt3_projects/vadinCA11/data/V11/genomes /ebio/abt3_projects/vadinCA11/data/V11/checkm_downloaded_genomes "
#
# *******************************************************************************
#  [CheckM - tree] Placing bins in reference genome tree.
# *******************************************************************************
#
#   Identifying marker genes in 78 bins with 8 threads:
#     Finished processing 78 of 78 (100.00%) bins.
#   Saving HMM info to file.
#
#   Calculating genome statistics for 78 bins with 8 threads:
#     Finished processing 78 of 78 (100.00%) bins.
#
#   Extracting marker genes to align.
#   Parsing HMM hits to marker genes:
#     Finished parsing hits for 32 of 78 (41.03%) bins.
# <b>limit_output extension: Maximum message size of 10000 exceeded with 10053 characters</b>

# %% [markdown]
# ## Check results

# %%
checkm_stats = "{0}/checkm_output/storage/bin_stats_ext.tsv".format(work_dir)
chepwdckm_df = pd.read_csv(checkm_stats, sep='\t', skiprows=0, header=None)
checkm_df = eval(chepwdckm_df.iat[0,1]) # Select only the stats from the V11 bin and turn into dict
checkm_df = pd.DataFrame(list(checkm_df.items()))
checkm_df.columns = ["Stat", "Value"]
checkm_df = checkm_df.set_index('Stat')
checkm_df = checkm_df.loc[["Completeness", "Contamination", "Genome size", "# ambiguous bases", 
               "# contigs", "Mean contig length", "N50 (contigs)", "Longest contig",
               "# scaffolds", "Mean scaffold length", "N50 (scaffolds)",
               "Longest scaffold", "GC", "GC std", "# predicted genes", 
               "Translation table", "Coding density", "marker lineage", "# genomes",
               "# markers", "# marker sets" ]]
checkm_df.rename(columns = {"Value": "V11_RL001"}, inplace=True)
checkm_df
# Out:
#                              V11_RL001
# Stat
# Completeness                   98.3871
# Contamination                        0
# Genome size                    1590932
# # ambiguous bases                    0
# # contigs                           48
# Mean contig length             33144.4
# N50 (contigs)                    50438
# Longest contig                  103078
# # scaffolds                         48
# Mean scaffold length           33144.4
# N50 (scaffolds)                  50438
# Longest scaffold                103078
# GC                            0.559415
# GC std                        0.016983
# # predicted genes                 1605
# Translation table                   11
# Coding density                0.892202
# marker lineage        p__Euryarchaeota
# # genomes                          148
# # markers                          187
# # marker sets                      124

# %%
# Summarize the CheckM results on downloaded genomes
checkm_stats = "{0}/checkm_downloaded_genomes/storage/bin_stats_ext.tsv".format(work_dir)
checkm_df = pd.read_csv(checkm_stats, sep='\t', skiprows=0, header=None)

# Names of assemblies
assemblies = list(checkm_df.iloc[:,0])
assemblies

# Create a single df with all results
summary_df = pd.DataFrame()
for i in checkm_df.iloc[:, 1]:
    tmp_df = eval(i)
    tmp_df = pd.DataFrame(list(tmp_df.items()))
    tmp_df.columns = ["Stat", "Value"]
    tmp_df = tmp_df.set_index('Stat')
    tmp_df = tmp_df.loc[["Completeness", "Contamination", "Genome size", "# ambiguous bases", 
               "# contigs", "Mean contig length", "N50 (contigs)", "Longest contig",
               "# scaffolds", "Mean scaffold length", "N50 (scaffolds)",
               "Longest scaffold", "GC", "GC std", "# predicted genes", 
               "Translation table", "Coding density", "marker lineage", "# genomes",
               "# markers", "# marker sets" ]]
    summary_df = pd.concat([summary_df, tmp_df], axis=1)

# Rename columns
summary_df.columns = assemblies
summary_df
# Out:
#                        GCA_000300255.2   GCA_002503545.1   GCA_002495495.1  \
# Stat
# Completeness                   98.3871           88.3788           86.2068
# Contamination                 0.806452           0.94086          0.403226
# Genome size                    1666795           1249378           1063745
# # ambiguous bases                    0              1306              6646
# # contigs                            1                56               107
# Mean contig length          1.6668e+06             22287           9879.43
# N50 (contigs)                  1666795             45710             16791
# Longest contig                 1666795             99237             55665
# # scaffolds                          1                34                80
# Mean scaffold length        1.6668e+06           36746.4           13296.8
# N50 (scaffolds)                1666795             54472             18039
# Longest scaffold               1666795            120572             76417
# GC                            0.555948          0.601188          0.564028
# GC std                               0         0.0170428         0.0200564
# # predicted genes                 1636              1279              1152
# Translation table                   11                11                11
# Coding density                0.893948          0.899556          0.914932
# marker lineage        p__Euryarchaeota  p__Euryarchaeota  p__Euryarchaeota
# # genomes                          148               148               148
# # markers                          187               187               187
# # marker sets                      124               124               124
#
#                        GCA_002506865.1   GCA_002499085.1   GCA_002494805.1  \
# Stat
# Completeness                   83.3633              76.8           92.3387
# Contamination                  4.03226               2.4          0.806452
# Genome size                    1104259           1749312           1648656
# # ambiguous bases                20303               479               790
# # contigs                          175                46                47
# Mean contig length             6194.03           38018.1             35061
# N50 (contigs)                    13507             56845             64245
# Longest contig                   44660            154585            269292
# # scaffolds                         58                37                36
# Mean scaffold length           19038.9           47278.7             45796
# N50 (scaffolds)                  41159             73068             66041
# Longest scaffold                119079            154591            291792
# GC                            0.555444          0.547508          0.574851
# GC std                       0.0181341          0.013905         0.0176275
# # predicted genes                 1206              1503              1564
# Translation table                   11                11                11
# Coding density                0.870157          0.890325          0.900677
# marker lineage        p__Euryarchaeota  p__Euryarchaeota  p__Euryarchaeota
# # genomes                          148               148               148
# # markers                          187               188               187
# # marker sets                      124               125               124
#
#                        GCA_002502545.1   GCA_000404225.1   GCA_002495125.1  \
# Stat
# Completeness                   88.4904           98.7903           65.0538
# Contamination                        0          0.806452                 0
# Genome size                    1115929           1931651            882347
# # ambiguous bases                17388                 0             21968
# # contigs                          135                 1               158
# Mean contig length             8137.34       1.93165e+06           5445.44
# N50 (contigs)                    25662           1931651             37789
# Longest contig                  103911           1931651             86336
# # scaffolds                         38                 1                20
# Mean scaffold length           29366.6       1.93165e+06           44117.3
# N50 (scaffolds)                  69703           1931651             63391
# Longest scaffold                140813           1931651            183706
# GC                            0.551633          0.412554          0.555003
# GC std                        0.019404                 0         0.0118407
# # predicted genes                 1187              1855               913
# Translation table                   11                11                11
# Coding density                0.883084          0.882898          0.865416
# marker lineage        p__Euryarchaeota  p__Euryarchaeota  p__Euryarchaeota
# # genomes                          148               148               148
# # markers                          187               187               187
# # marker sets                      124               124               124
#
#                        GCA_002498765.1        ...          GCA_002503785.1  \
# Stat                                          ...
# Completeness                   95.0775        ...                  96.9086
# Contamination                        0        ...                        0
# Genome size                    1174624        ...                  1308604
# # ambiguous bases                10307        ...                      383
# # contigs                           66        ...                       22
# Mean contig length             17641.2        ...                  59464.6
# N50 (contigs)                   135661        ...                   102142
# Longest contig                  270640        ...                   181776
# # scaffolds                         29        ...                       12
# Mean scaffold length           40504.3        ...                   109050
# N50 (scaffolds)                 163880        ...                   128983
# Longest scaffold                270640        ...                   181778
# GC                            0.554079        ...                 0.543219
# GC std                       0.0175766        ...                0.0162278
# # predicted genes                 1240        ...                     1348
# Translation table                   11        ...                       11
# Coding density                0.900474        ...                 0.925829
# marker lineage        p__Euryarchaeota        ...         p__Euryarchaeota
# # genomes                          148        ...                      148
# # markers                          187        ...                      187
# # marker sets                      124        ...                      124
#
#                        GCA_900313075.1   GCA_002505245.1   GCA_002508585.1  \
# Stat
# Completeness                   82.2581           95.5645           88.3002
# Contamination                  2.41935                 0          0.806452
# Genome size                    1262884           1175704           1883692
# # ambiguous bases                    0              5963             74196
# # contigs                          192                49               464
# Mean contig length             6577.52           23872.3           3899.78
# N50 (contigs)                     8388             46981              7813
# Longest contig                   35746            122573             40576
# # scaffolds                        192                16               144
# Mean scaffold length           6577.52           73481.5           13081.2
# N50 (scaffolds)                   8388            117614             18257
# Longest scaffold                 35746            414343            109207
# GC                            0.616806          0.551546          0.613088
# GC std                       0.0220273         0.0109465         0.0215446
# # predicted genes                 1374              1212              2144
# Translation table                   11                11                11
# Coding density                0.909772           0.91466          0.821946
# marker lineage        p__Euryarchaeota  p__Euryarchaeota  p__Euryarchaeota
# # genomes                          148               148               148
# # markers                          187               187               187
# # marker sets                      124               124               124
#
#                        GCA_002508545.1   GCA_002509415.1   GCA_002494945.1  \
# Stat
# Completeness                   97.3118            88.936           64.0521
# Contamination                 0.806452                 0                 0
# Genome size                    2360299           1123872            869682
# # ambiguous bases                 2392             23022             22328
# # contigs                          111               138               216
# Mean contig length             21242.4           7977.17           3922.94
# N50 (contigs)                    46502             21846              7750
# Longest contig                  119060             49127             31952
# # scaffolds                         68                42                95
# Mean scaffold length           34710.3           26758.9           9154.55
# N50 (scaffolds)                  59274             44966             12321
# Longest scaffold                119078            104203             36651
# GC                            0.627406          0.553595          0.556602
# GC std                       0.0215979         0.0177516         0.0204313
# # predicted genes                 2497              1192               960
# Translation table                   11                11                11
# Coding density                0.881767          0.886052          0.869988
# marker lineage        p__Euryarchaeota  p__Euryarchaeota  p__Euryarchaeota
# # genomes                          148               148               148
# # markers                          187               187               187
# # marker sets                      124               124               124
#
#                        GCA_002506255.1   GCA_002498425.1   GCA_002496945.1
# Stat
# Completeness                   61.1559           90.7258            97.135
# Contamination                 0.806452                 0                 0
# Genome size                     823014           1224361           1401758
# # ambiguous bases                26401              5065              6936
# # contigs                          223                38                60
# Mean contig length             3572.26           32086.7             23247
# N50 (contigs)                     6129             55747             49812
# Longest contig                   23521            153909            136345
# # scaffolds                         93                15                24
# Mean scaffold length           8849.61           81624.1           58406.6
# N50 (scaffolds)                  12087            116637            100729
# Longest scaffold                 36878            234605            293218
# GC                             0.53087          0.560651          0.516718
# GC std                        0.021296         0.0146937         0.0184419
# # predicted genes                  917              1278              1521
# Translation table                   11                11                11
# Coding density                 0.84989          0.912572          0.893666
# marker lineage        p__Euryarchaeota  p__Euryarchaeota  p__Euryarchaeota
# # genomes                          148               148               148
# # markers                          187               187               187
# # marker sets                      124               124               124
#
# [21 rows x 78 columns]

# %%
# Select only substantially complete genomes (>= 70%) with low contamination (<= 5%)
complete = summary_df.loc['Completeness'] >= 70
non_contaminated = summary_df.loc['Contamination'] <= 5
# Summary of included
include = complete & non_contaminated
include_df = summary_df.loc[: , include]
# Summary of excluded
exclude = ~(summary_df.columns.isin(include_df.columns))
exclude_df = summary_df.loc[: , exclude]

# %%
# Table with genome statistics of included
include_df = pd.concat([checkm_df, include_df], axis=1)
included_stats = os.path.join(download_folder, "included_stats.txt")
include_df.to_csv(included_stats, sep='\t')

# %%
include_df
# Out:
#                              V11_RL001   GCA_000300255.2   GCA_002503545.1  \
# Stat
# Completeness                   98.3871           98.3871           88.3788
# Contamination                        0          0.806452           0.94086
# Genome size                    1590932           1666795           1249378
# # ambiguous bases                    0                 0              1306
# # contigs                           48                 1                56
# Mean contig length             33144.4        1.6668e+06             22287
# N50 (contigs)                    50438           1666795             45710
# Longest contig                  103078           1666795             99237
# # scaffolds                         48                 1                34
# Mean scaffold length           33144.4        1.6668e+06           36746.4
# N50 (scaffolds)                  50438           1666795             54472
# Longest scaffold                103078           1666795            120572
# GC                            0.559415          0.555948          0.601188
# GC std                        0.016983                 0         0.0170428
# # predicted genes                 1605              1636              1279
# Translation table                   11                11                11
# Coding density                0.892202          0.893948          0.899556
# marker lineage        p__Euryarchaeota  p__Euryarchaeota  p__Euryarchaeota
# # genomes                          148               148               148
# # markers                          187               187               187
# # marker sets                      124               124               124
#
#                        GCA_002495495.1   GCA_002506865.1   GCA_002499085.1  \
# Stat
# Completeness                   86.2068           83.3633              76.8
# Contamination                 0.403226           4.03226               2.4
# Genome size                    1063745           1104259           1749312
# # ambiguous bases                 6646             20303               479
# # contigs                          107               175                46
# Mean contig length             9879.43           6194.03           38018.1
# N50 (contigs)                    16791             13507             56845
# Longest contig                   55665             44660            154585
# # scaffolds                         80                58                37
# Mean scaffold length           13296.8           19038.9           47278.7
# N50 (scaffolds)                  18039             41159             73068
# Longest scaffold                 76417            119079            154591
# GC                            0.564028          0.555444          0.547508
# GC std                       0.0200564         0.0181341          0.013905
# # predicted genes                 1152              1206              1503
# Translation table                   11                11                11
# Coding density                0.914932          0.870157          0.890325
# marker lineage        p__Euryarchaeota  p__Euryarchaeota  p__Euryarchaeota
# # genomes                          148               148               148
# # markers                          187               187               188
# # marker sets                      124               124               125
#
#                        GCA_002494805.1   GCA_002502545.1   GCA_000404225.1  \
# Stat
# Completeness                   92.3387           88.4904           98.7903
# Contamination                 0.806452                 0          0.806452
# Genome size                    1648656           1115929           1931651
# # ambiguous bases                  790             17388                 0
# # contigs                           47               135                 1
# Mean contig length               35061           8137.34       1.93165e+06
# N50 (contigs)                    64245             25662           1931651
# Longest contig                  269292            103911           1931651
# # scaffolds                         36                38                 1
# Mean scaffold length             45796           29366.6       1.93165e+06
# N50 (scaffolds)                  66041             69703           1931651
# Longest scaffold                291792            140813           1931651
# GC                            0.574851          0.551633          0.412554
# GC std                       0.0176275          0.019404                 0
# # predicted genes                 1564              1187              1855
# Translation table                   11                11                11
# Coding density                0.900677          0.883084          0.882898
# marker lineage        p__Euryarchaeota  p__Euryarchaeota  p__Euryarchaeota
# # genomes                          148               148               148
# # markers                          187               187               187
# # marker sets                      124               124               124
#
#                        GCA_002498765.1        ...          GCA_002498285.1  \
# Stat                                          ...
# Completeness                   95.0775        ...                  84.7177
# Contamination                        0        ...                        0
# Genome size                    1174624        ...                  1827384
# # ambiguous bases                10307        ...                    98446
# # contigs                           66        ...                      572
# Mean contig length             17641.2        ...                  3022.62
# N50 (contigs)                   135661        ...                     7077
# Longest contig                  270640        ...                    71752
# # scaffolds                         29        ...                      110
# Mean scaffold length           40504.3        ...                  16612.6
# N50 (scaffolds)                 163880        ...                    30094
# Longest scaffold                270640        ...                    98428
# GC                            0.554079        ...                 0.620404
# GC std                       0.0175766        ...                0.0187164
# # predicted genes                 1240        ...                     2237
# Translation table                   11        ...                       11
# Coding density                0.900474        ...                 0.797884
# marker lineage        p__Euryarchaeota        ...         p__Euryarchaeota
# # genomes                          148        ...                      148
# # markers                          187        ...                      187
# # marker sets                      124        ...                      124
#
#                        GCA_002509465.1   GCA_002503785.1   GCA_900313075.1  \
# Stat
# Completeness                   84.7455           96.9086           82.2581
# Contamination                        0                 0           2.41935
# Genome size                     969311           1308604           1262884
# # ambiguous bases                 5047               383                 0
# # contigs                          104                22               192
# Mean contig length             9271.77           59464.6           6577.52
# N50 (contigs)                    15368            102142              8388
# Longest contig                   40716            181776             35746
# # scaffolds                         69                12               192
# Mean scaffold length             14048            109050           6577.52
# N50 (scaffolds)                  17909            128983              8388
# Longest scaffold                 40716            181778             35746
# GC                            0.564198          0.543219          0.616806
# GC std                       0.0189734         0.0162278         0.0220273
# # predicted genes                 1057              1348              1374
# Translation table                   11                11                11
# Coding density                0.918026          0.925829          0.909772
# marker lineage        p__Euryarchaeota  p__Euryarchaeota  p__Euryarchaeota
# # genomes                          148               148               148
# # markers                          187               187               187
# # marker sets                      124               124               124
#
#                        GCA_002505245.1   GCA_002508585.1   GCA_002508545.1  \
# Stat
# Completeness                   95.5645           88.3002           97.3118
# Contamination                        0          0.806452          0.806452
# Genome size                    1175704           1883692           2360299
# # ambiguous bases                 5963             74196              2392
# # contigs                           49               464               111
# Mean contig length             23872.3           3899.78           21242.4
# N50 (contigs)                    46981              7813             46502
# Longest contig                  122573             40576            119060
# # scaffolds                         16               144                68
# Mean scaffold length           73481.5           13081.2           34710.3
# N50 (scaffolds)                 117614             18257             59274
# Longest sca
# <b>limit_output extension: Maximum message size of 10000 exceeded with 12564 characters</b>

# %%
exclude_df.columns.tolist()
# Out:
# ['GCA_002495125.1',
#  'GCA_002497815.1',
#  'GCA_002505735.1',
#  'GCA_002502165.1',
#  'GCA_002497195.1',
#  'GCA_002494945.1',
#  'GCA_002506255.1']

# %%
# Write file with the paths of the V11 bin and the included genomes
include_file = os.path.join(download_folder, "included_genomes.txt")
with open(include_file, "a") as myfile:
    myfile.write(V11_bin + "\n") # V11
    for inclusion in include_df.columns.tolist():
        filename = os.path.join (download_folder, (inclusion + ".fna"))
        myfile.write(filename + "\n") # Each included genome

# %% [markdown]
# # *Thermoplasmata* genomes
# For the phylogenomic analyses, I need an outgroup. For this I will use several genomes from organisms of the class Thermoplasmata. I will download their genome sequences and proteomes.

# %%
# Create folder and save accessions
Thermoplasmata_folder = os.path.join(work_dir, "genomes", "Thermoplasmata")
if not os.path.exists(Thermoplasmata_folder):
    os.makedirs(Thermoplasmata_folder)
Thermoplasmata_list = os.path.join(Thermoplasmata_folder, "Thermoplasmata.csv")

# %%
# I will include RefSeq representative genomes
Thermoplasmata_members = ["GCA_000195915.1", "GCA_900176435.1", 
                          "GCA_000152265.2", "GCA_001402945.1", 
                          "GCA_900090055.1"]

Thermoplasmata_newname = ["GCA_000195915", "GCA_900176435", 
                          "GCA_000152265", "GCA_001402945", 
                          "GCA_900090055"]

# %%
# Download genome assemblies in fasta format from NCBI
Thermoplasmata = get_members(Thermoplasmata_members, 
                                Thermoplasmata_folder, 
                                Thermoplasmata_list)

# %%
# Uncompress genome files
gunzip_job = "gunzip {0}/*.fna.gz".format(Thermoplasmata_folder)
print(gunzip_job)
# !$gunzip_job
# Out:
# gunzip /ebio/abt3_projects/vadinCA11/data/V11/genomes/Thermoplasmata/*.fna.gz

# %%
# Fix file names
for f in os.listdir(Thermoplasmata_folder):
    f_new = re.sub('_[a-zA-Z].*_genomic', '', f)
    os.rename(f, f.replace(f, f_new))

# %%
# Print table with accessions
Thermoplasmata_df = pd.read_csv(Thermoplasmata_list, sep=',', header=0)
Thermoplasmata_df = Thermoplasmata_df.drop(["Unnamed: 0"], axis=1)
Thermoplasmata_df
# Out:
#                                   Assembly                           Organism  \
# 0                               ASM19591v1  Thermoplasma acidophilum DSM 1728
# 1  IMG-taxon 2579779151 annotated assembly       Picrophilus oshimae DSM 9789
# 2                               ASM15226v2       Ferroplasma acidarmanus fer1
# 3                              ASM140294v1               Acidiplasma aeolicum
# 4                         C.divulgatum PM4          Cuniculiplasma divulgatum
#
#          Accession
# 0  GCA_000195915.1
# 1  GCA_900176435.1
# 2  GCA_000152265.2
# 3  GCA_001402945.1
# 4  GCA_900090055.1

# %%
# Download proteomes
# Download Thermoplasmata prots
Thermoplasma = "ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/195/915/GCF_000195915.1_ASM19591v1/GCF_000195915.1_ASM19591v1_protein.faa.gz"
Picrophilus = "ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/900/176/435/GCF_900176435.1_IMG-taxon_2579779151_annotated_assembly/GCF_900176435.1_IMG-taxon_2579779151_annotated_assembly_protein.faa.gz"
Ferroplasma = "ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/152/265/GCF_000152265.2_ASM15226v2/GCF_000152265.2_ASM15226v2_protein.faa.gz"
Acidiplasma = "ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/001/402/945/GCF_001402945.1_ASM140294v1/GCF_001402945.1_ASM140294v1_protein.faa.gz"
Cuniculiplasma = "ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/900/090/055/GCF_900090055.1_C.divulgatum_PM4/GCF_900090055.1_C.divulgatum_PM4_protein.faa.gz"

Thermoplasmata_prots = [Thermoplasma, Picrophilus, Ferroplasma, Acidiplasma, Cuniculiplasma]

# download command
download_cmd = "wget {0} --output-document {1}/{3}.faa.gz; gunzip {1}/{3}.faa.gz"
for T in range(0, len(Thermoplasmata_prots)):
    download_job = download_cmd.format(Thermoplasmata_prots[T], 
                                       Thermoplasmata_folder, 
                                       Thermoplasmata_members[T], 
                                       Thermoplasmata_newname[T])
    print(download_job)
    # !$download_job
# Out:
# wget ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/195/915/GCF_000195915.1_ASM19591v1/GCF_000195915.1_ASM19591v1_protein.faa.gz --output-document /ebio/abt3_projects/vadinCA11/data/V11/genomes/Thermoplasmata/GCA_000195915.faa.gz; gunzip /ebio/abt3_projects/vadinCA11/data/V11/genomes/Thermoplasmata/GCA_000195915.faa.gz
# --2019-01-25 10:11:20--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/195/915/GCF_000195915.1_ASM19591v1/GCF_000195915.1_ASM19591v1_protein.faa.gz
#            => ‘/ebio/abt3_projects/vadinCA11/data/V11/genomes/Thermoplasmata/GCA_000195915.faa.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.7, 2607:f220:41e:250::11
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.7|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCF/000/195/915/GCF_000195915.1_ASM19591v1 ... done.
# ==> SIZE GCF_000195915.1_ASM19591v1_protein.faa.gz ... 298504
# ==> PASV ... done.    ==> RETR GCF_000195915.1_ASM19591v1_protein.faa.gz ... done.
# Length: 298504 (292K) (unauthoritative)
#
# GCF_000195915.1_ASM 100%[===================>] 291.51K   750KB/s    in 0.4s
#
# 2019-01-25 10:11:21 (750 KB/s) - ‘/ebio/abt3_projects/vadinCA11/data/V11/genomes/Thermoplasmata/GCA_000195915.faa.gz’ saved [298504]
#
# wget ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/900/176/435/GCF_900176435.1_IMG-taxon_2579779151_annotated_assembly/GCF_900176435.1_IMG-taxon_2579779151_annotated_assembly_protein.faa.gz --output-document /ebio/abt3_projects/vadinCA11/data/V11/genomes/Thermoplasmata/GCA_900176435.faa.gz; gunzip /ebio/abt3_projects/vadinCA11/data/V11/genomes/Thermoplasmata/GCA_900176435.faa.gz
# --2019-01-25 10:11:22--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/900/176/435/GCF_900176435.1_IMG-taxon_2579779151_annotated_assembly/GCF_900176435.1_IMG-taxon_2579779151_annotated_assembly_protein.faa.gz
#            => ‘/ebio/abt3_projects/vadinCA11/data/V11/genomes/Thermoplasmata/GCA_900176435.faa.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.7, 2607:f220:41e:250::11
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.7|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCF/900/176/435/GCF_900176435.1_IMG-taxon_2579779151_annotated_assembly ... done.
# ==> SIZE GCF_900176435.1_IMG-taxon_2579779151_annotated_assembly_protein.faa.gz ... 300255
# ==> PASV ... done.    ==> RETR GCF_900176435.1_IMG-taxon_2579779151_annotated_assembly_protein.faa.gz ... done.
# Length: 300255 (293K) (unauthoritative)
#
# GCF_900176435.1_IMG 100%[===================>] 293.22K   755KB/s    in 0.4s
#
# 2019-01-25 10:11:23 (755 KB/s) - ‘/ebio/abt3_projects/vadinCA11/data/V11/genomes/Thermoplasmata/GCA_900176435.faa.gz’ saved [300255]
#
# wget ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/152/265/GCF_000152265.2_ASM15226v2/GCF_000152265.2_ASM15226v2_protein.faa.gz --output-document /ebio/abt3_projects/vadinCA11/data/V11/genomes/Thermoplasmata/GCA_000152265.faa.gz; gunzip /ebio/abt3_projects/vadinCA11/data/V11/genomes/Thermoplasmata/GCA_000152265.faa.gz
# --2019-01-25 10:11:23--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/152/265/GCF_000152265.2_ASM15226v2/GCF_000152265.2_ASM15226v2_protein.faa.gz
#            => ‘/ebio/abt3_projects/vadinCA11/data/V11/genomes/Thermoplasmata/GCA_000152265.faa.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.7, 2607:f220:41e:250::11
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.7|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCF/000/152/265/GCF_000152265.2_ASM15226v2 ... done.
# ==> SIZE GCF_000152265.2_ASM15226v2_protein.faa.gz ... 362596
# ==> PASV ... done.    ==> RETR GCF_000152265.2_ASM15226v2_protein.faa.gz ... done.
# Length: 362596 (354K) (unauthoritative)
#
# GCF_000152265.2_ASM 100%[===================>] 354.10K   912KB/s    in 0.4s
#
# 2019-01-25 10:11:25 (912 KB/s) - ‘/ebio/abt3_projects/vadinCA11/data/V11/genomes/Thermoplasmata/GCA_000152265.faa.gz’ saved [362596]
#
# wget ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/001/402/945/GCF_001402945.1_ASM140294v1/GCF_001402945.1_ASM140294v1_protein.faa.gz --output-document /ebio/abt3_projects/vadinCA11/data/V11/genomes/Thermoplasmata/GCA_001402945.faa.gz; gunzip /ebio/abt3_projects/vadinCA11/data/V11/genomes/Thermoplasmata/GCA_001402945.faa.gz
# --2019-01-25 10:11:25--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/001/402/945/GCF_001402945.1_ASM140294v1/GCF_001402945.1_ASM140294v1_protein.faa.gz
#            => ‘/ebio/abt3_projects/vadinCA11/data/V11/genomes/Thermoplasmata/GCA_001402945.faa.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.7, 2607:f220:41e:250::11
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.7|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCF/001/402/945/GCF_001402945.1_ASM140294v1 ... done.
# ==> SIZE GCF_001402945.1_ASM140294v1_protein.faa.gz ... 322914
# ==> PASV ... done.    ==> RETR GCF_001402945.1_ASM140294v1_protein.faa.gz ... done.
# Length: 322914 (315K) (unauthoritative)
#
# GCF_001402945.1_ASM 100%[===================>] 315.35K   814KB/s    in 0.4s
#
# 2019-01-25 10:11:27 (814 KB/s) - ‘/ebio/abt3_projects/vadinCA11/data/V11/genomes/Thermoplasmata/GCA_001402945.faa.gz’ saved [322914]
#
# wget ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/900/090/055/GCF_900090055.1_C.divulgatum_PM4/GCF_900090055.1_C.divulgatum_PM4_protein.faa.gz --output-document /ebio/abt3_projects/vadinCA11/data/V11/genomes/Thermoplasmata/GCA_900090055.faa.gz; gunzip /ebio/abt3_projects/vadinCA11/data/V11/genomes/Thermoplasmata/GCA_900090055.faa.gz
# --2019-01-25 10:11:27--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/900/090/055/GCF_900090055.1_C.divulgatum_PM4/GCF_900090055.1_C.divulgatum_PM4_protein.faa.gz
#            => ‘/ebio/abt3_projects/vadinCA11/data/V11/genomes/Thermoplasmata/GCA_900090055.faa.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.7, 2607:f220:41e:250::11
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.7|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCF/900/090/055/GCF_900090055.1_C.divulgatum_PM4 ... done.
# ==> SIZE GCF_900090055.1_C.divulgatum_PM4_protein.faa.gz ... 354026
# ==> PASV ... done.    ==> RETR GCF_900090055.1_C.divulgatum_PM4_protein.faa.gz ... done.
# Length: 354026 (346K) (unauthoritative)
#
# GCF_900090055.1_C.d 100%[===================>] 345.73K   879KB/s    in 0.4s
#
# 2019-01-25 10:11:29 (879 KB/s) - ‘/ebio/abt3_projects/vadinCA11/data/V11/genomes/Thermoplasmata/GCA_900090055.faa.gz’ saved [354026]

# %% [markdown]
# # Session info

# %%
# !conda list -n metacompass
# Out:
# # packages in environment at /ebio/abt3_projects/software/miniconda3_gt4.4/envs/metacompass:
# #
# # Name                    Version                   Build  Channel
# aioeasywebdav             2.2.0                    py36_0    conda-forge
# aiohttp                   3.4.4            py36h470a237_0    conda-forge
# anvio                     5.1.0            py36hcb787e7_1    bioconda
# appdirs                   1.4.3                      py_1    conda-forge
# aragorn                   1.2.38               h470a237_2    bioconda
# asn1crypto                0.24.0                     py_1    conda-forge
# async-timeout             3.0.1                   py_1000    conda-forge
# attrs                     18.1.0                     py_1    conda-forge
# automat                   0.7.0                    py36_0    conda-forge
# backcall                  0.1.0                      py_0    conda-forge
# barrnap                   0.9                           2    bioconda
# bcftools                  1.9                  h4da6232_0    bioconda
# bcrypt                    3.1.4            py36h470a237_0    conda-forge
# bedtools                  2.27.1               he941832_2    bioconda
# biopython                 1.72                     py36_0    conda-forge
# blas                      1.1                    openblas    conda-forge
# blast                     2.7.1                h4422958_6    bioconda
# blast-legacy              2.2.26                        1    bioconda
# bleach                    2.1.3                      py_0    conda-forge
# boost                     1.67.0           py36h3e44d54_0    conda-forge
# boost-cpp                 1.67.0               h3a22d5f_0    conda-forge
# boto3                     1.7.84                     py_0    conda-forge
# botocore                  1.10.84                    py_0    conda-forge
# bottle                    0.12.13                    py_1    conda-forge
# bzip2                     1.0.6                h470a237_2    conda-forge
# ca-certificates           2018.4.16                     0    conda-forge
# cachetools                2.1.0                      py_0    conda-forge
# cairo                     1.14.12              he56eebe_3    conda-forge
# certifi                   2018.4.16                py36_0    conda-forge
# cffi                      1.11.5           py36h5e8e0c9_1    conda-forge
# chardet                   3.0.4                 py36_1003    conda-forge
# cherrypy                  8.0.0                    py36_0    conda-forge
# configargparse            0.13.0                     py_1    conda-forge
# constantly                15.1.0                     py_0    conda-forge
# cryptography              2.3              py36hdffb7b8_0    conda-forge
# cryptography-vectors      2.3                      py36_1    conda-forge
# curl                      7.61.0               h93b3f91_1    conda-forge
# cycler                    0.10.0                     py_1    conda-forge
# datrie                    0.7.1                    py36_0
# dbus                      1.13.0               h3a4f0e9_0    conda-forge
# decorator                 4.3.0                      py_0    conda-forge
# django                    2.0.2                    py36_0    conda-forge
# docutils                  0.14                  py36_1001    conda-forge
# dropbox                   7.3.1                    py36_0    conda-forge
# entrypoints               0.2.3                    py36_1    conda-forge
# ete3                      3.1.1                    py36_0    bioconda
# expat                     2.2.5                hfc679d8_2    conda-forge
# filechunkio               1.6                      py36_0    bioconda
# fontconfig                2.13.0               h0c61d53_4    conda-forge
# freetype                  2.8.1                hfa320df_1    conda-forge
# ftputil                   3.2                      py36_0    bioconda
# gettext                   0.19.8.1                      0    conda-forge
# glib                      2.55.0               h464dc38_2    conda-forge
# gmp                       6.1.2                hfc679d8_0    conda-forge
# gnutls                    3.5.19               h2a4e5f8_1    conda-forge
# google-auth               1.6.1                      py_0    conda-forge
# google-auth-httplib2      0.0.3                      py_2    conda-forge
# google-cloud-core         0.24.1                   py36_0    conda-forge
# google-cloud-storage      1.1.1                    py36_0    conda-forge
# google-resumable-media    0.0.2                    py36_0    conda-forge
# googleapis-common-protos  1.5.5                      py_0    conda-forge
# graphite2                 1.3.11               hfc679d8_0    conda-forge
# gsl                       2.2.1           blas_openblas_4  [blas_openblas]  conda-forge
# gst-plugins-base          1.12.5               hde13a9d_0    conda-forge
# gstreamer                 1.12.5               h61a6719_0    conda-forge
# h5py                      2.8.0            py36he5c79e1_5    conda-forge
# harfbuzz                  1.8.5                h2bb21d5_0    conda-forge
# hdf5                      1.10.4          nompi_h5598ddc_1003    conda-forge
# hmmer                     3.2.1                hfc679d8_0    bioconda
# html5lib                  1.0.1                      py_0    conda-forge
# htslib                    1.7                           0    bioconda
# httplib2                  0.12.0                py36_1000    conda-forge
# hyperlink                 17.3.1                     py_0    conda-forge
# icu                       58.2                 hfc679d8_0    conda-forge
# idna                      2.7                      py36_2    conda-forge
# idna_ssl                  1.0.0                         0    conda-forge
# incremental               17.5.0                     py_0    conda-forge
# infernal                  1.1.2                h470a237_1    bioconda
# ipykernel                 4.8.2                    py36_0    conda-forge
# ipython                   6.5.0                    py36_0    conda-forge
# ipython_genutils          0.2.0                      py_1    conda-forge
# java-jdk                  8.0.92                        1    bioconda
# jedi                      0.12.1                   py36_0    conda-forge
# jellyfish                 1.1.12               h2d50403_0    bioconda
# jinja2                    2.10                       py_1    conda-forge
# jmespath                  0.9.3                      py_1    conda-forge
# jpeg                      9c                   h470a237_0    conda-forge
# jsonschema                2.6.0                    py36_1    conda-forge
# jupyter_client            5.2.3                      py_1    conda-forge
# jupyter_core              4.4.0                      py_0    conda-forge
# jupyterlab                0.35.4                   py36_0    conda-forge
# jupyterlab_server         0.2.0                      py_0    conda-forge
# kiwisolver                1.0.1            py36h2d50403_2    conda-forge
# kraken2                   2.0.7_beta      pl526h2d50403_0    bioconda
# krb5                      1.14.6                        0    conda-forge
# libdeflate                1.0                  h470a237_0    bioconda
# libffi                    3.2.1                         3    conda-forge
# libgcc                    7.2.0                h69d50b8_2
# libgcc-ng                 7.2.0                hdf63c60_3
# libgfortran               3.0.0                         1
# libgfortran-ng            7.2.0                hdf63c60_3
# libiconv                  1.15                 h470a237_1    conda-forge
# libidn11                  1.33                          0    conda-forge
# libopenblas               0.2.20               h9ac9557_7
# libpng                    1.6.35               ha92aebf_0    conda-forge
# libprotobuf               3.6.1                hd28b015_0    conda-forge
# libsodium                 1.0.16                        0    conda-forge
# libssh2                   1.8.0                h5b517e9_2    conda-forge
# libstdcxx-ng              7.2.0                hdf63c60_3
# libtiff                   4.0.9                he6b73bb_1    conda-forge
# libuuid                   1.0.3                         1    conda-forge
# libxcb                    1.13                 h470a237_2    conda-forge
# libxml2                   2.9.8                h422b904_2    conda-forge
# libxslt                   1.1.32               h88dbc4e_2    conda-forge
# lxml                      4.2.5            py36hc9114bc_0    conda-forge
# markupsafe                1.0                      py36_0    conda-forge
# matplotlib                2.2.2            py36h0e671d2_0
# mcl                       14.137          pl526h470a237_4    bioconda
# minced                    0.2.0                         0    bioconda
# mistune                   0.7.4                    py36_0    conda-forge
# multidict                 4.5.1            py36h470a237_0    conda-forge
# mummer                    3.23                    pl526_6    bioconda
# muscle                    3.8.1551             h2d50403_3    bioconda
# nb_conda                  2.2.1                    py36_0    conda-forge
# nb_conda_kernels          2.1.1                    py36_1    conda-forge
# nbconvert                 5.3.1                      py_1    conda-forge
# nbformat                  4.4.0                      py_1    conda-forge
# ncurses                   6.1                  hfc679d8_1    conda-forge
# nettle                    3.3                           0    conda-forge
# notebook                  5.6.0                    py36_0    conda-forge
# numpy                     1.15.0          py36_blas_openblashd3ea46f_200  [blas_openblas]  conda-forge
# numpy-base                1.14.3           py36h0ea5e3f_1
# openblas                  0.2.20                        8    conda-forge
# openssl                   1.0.2o               h470a237_1    conda-forge
# pandas                    0.23.4           py36hf8a1672_0    conda-forge
# pandoc                    2.2.2                         1    conda-forge
# pandocfilters             1.4.2                      py_1    conda-forge
# pango                     1.40.14              h9105a7a_2    conda-forge
# parallel                  20160622                      1    bioconda
# parallel-fastq-dump       0.6.3                    py36_1    bioconda
# paramiko                  2.4.2                 py36_1000    conda-forge
# parso                     0.3.1                      py_0    conda-forge
# patsy                     0.5.1                      py_0    conda-forge
# pcre                      8.41                 h470a237_2    conda-forge
# perl                      5.26.2               h470a237_0    conda-forge
# perl-app-cpanminus        1.7044                  pl526_1    bioconda
# perl-archive-tar          2.18                    pl526_3    bioconda
# perl-bioperl              1.6.924                       4    bioconda
# perl-carp                 1.38                    pl526_1    bioconda
# perl-compress-raw-bzip2   2.074           pl526hfc679d8_0    bioconda
# perl-compress-raw-zlib    2.081           pl526h2d50403_0    bioconda
# perl-constant             1.33                    pl526_1    bioconda
# perl-data-dumper          2.161                   pl526_2    bioconda
# perl-encode               2.88                    pl526_1    bioconda
# perl-exporter             5.72                    pl526_1    bioconda
# perl-exporter-tiny        1.000000                pl526_0    bioconda
# perl-extutils-makemaker   7.34                    pl526_2    bioconda
# perl-file-path            2.15                    pl526_0    bioconda
# perl-file-temp            0.2304                  pl526_2    bioconda
# perl-io-compress          2.069           pl526hfc679d8_5    bioconda
# perl-io-zlib              1.10                    pl526_2    bioconda
# perl-list-moreutils       0.428                   pl526_1    bioconda
# perl-list-moreutils-xs    0.428                   pl526_0    bioconda
# perl-parent               0.236                   pl526_1    bioconda
# perl-pathtools            3.73                 h470a237_2    bioconda
# perl-scalar-list-utils    1.45            pl526h470a237_3    bioconda
# perl-test-more            1.001002                pl526_1    bioconda
# perl-threaded             5.22.0                       13    bioconda
# perl-xml-namespacesupport 1.12                    pl526_0    bioconda
# perl-xml-parser           2.44            pl526h3a4f0e9_6    bioconda
# perl-xml-sax              1.00                    pl526_0    bioconda
# perl-xml-sax-base         1.09                    pl526_0    bioconda
# perl-xml-sax-expat        0.51                    pl526_2    bioconda
# perl-xml-simple           2.22                    pl526_3    bioconda
# perl-xsloader             0.24                    pl526_0    bioconda
# perl-yaml                 1.26                    pl526_1    bioconda
# pexpect                   4.6.0                    py36_0    conda-forge
# pickleshare               0.7.4                    py36_0    conda-forge
# pip                       18.0                     py36_1    conda-forge
# pixman                    0.34.0                        2    conda-forge
# prettytable               0.7.2                      py_3    conda-forge
# prodigal                  2.6.3                         1    bioconda
# prokka                    1.13                          2    bioconda
# prometheus_client         0.3.0                      py_0    conda-forge
# prompt_toolkit            1.0.15                   py36_0    conda-forge
# protobuf                  3.6.1            py36hfc679d8_1    conda-forge
# psutil                    5.4.8            py36h470a237_0    conda-forge
# pthread-stubs             0.4                  h470a237_1    conda-forge
# ptyprocess                0.6.0                    py36_0    conda-forge
# pyani                     0.2.7            py36h24bf2e0_1    bioconda
# pyasn1                    0.4.4                      py_0    conda-forge
# pyasn1-modules            0.2.1                      py_0    conda-forge
# pycparser                 2.18                       py_1    conda-forge
# pygments                  2.2.0                      py_1    conda-forge
# pyhamcrest                1.9.0                      py_2    conda-forge
# pynacl                    1.3.0            py36h470a237_0    conda-forge
# pyopenssl                 18.0.0                   py36_0    conda-forge
# pyparsing                 2.2.2                      py_0    conda-forge
# pyqt                      5.6.0            py36h8210e8a_7    conda-forge
# pysam                     0.14.1           py36hae42fb6_1    bioconda
# pysftp                    0.2.9                    py36_0    bioconda
# python                    3.6.6                h5001a0f_0    conda-forge
# python-dateutil           2.7.3                      py_0    conda-forge
# python-irodsclient        0.7.0                      py_0    conda-forge
# pytz                      2018.5                     py_0    conda-forge
# pyyaml                    3.13             py36h470a237_1    conda-forge
# pyzmq                     17.1.0           py36hae99301_0    conda-forge
# qt                        5.6.2                h50c60fd_8    conda-forge
# r-assertthat              0.2.0                  r3.4.1_0    conda-forge
# r-base                    3.4.1                h4fe35fd_8    conda-forge
# r-base64enc               0.1_3            r341h470a237_1    conda-forge
# r-bh                      1.66.0_1               r3.4.1_0    conda-forge
# r-bindr                   0.1.1                  r3.4.1_0    conda-forge
# r-bindrcpp                0.2.2            r341h9d2a408_0    conda-forge
# r-bit                     1.1_12           r341h470a237_1    conda-forge
# r-bit64                   0.9_5            r341h470a237_1    conda-forge
# r-blob                    1.1.1                  r3.4.1_0    conda-forge
# r-boot                    1.3_19                 r3.4.1_0    r
# r-cli                     1.0.0                  r3.4.1_0    conda-forge
# r-crayon                  1.3.4                  r3.4.1_0    conda-forge
# r-dbi                     1.0.0                    r341_0    conda-forge
# r-dbplyr                  1.2.2                    r341_0    conda-forge
# r-digest                  0.6.15           r341h470a237_1    conda-forge
# r-dplyr                   0.7.6            r341h9d2a408_0    conda-forge
# r-evaluate                0.10.1                 r3.4.1_0    conda-forge
# r-glue                    1.3.0            r341h470a237_1    conda-forge
# r-htmltools               0.3.6            r341hfc679d8_1    conda-forge
# r-irdisplay               0.4.4                  r3.4.1_0    conda-forge
# r-irkernel                0.8.12                   r341_0    conda-forge
# r-jsonlite                1.5              r341h470a237_1    conda-forge
# r-magrittr                1.5                    r3.4.1_0    conda-forge
# r-memoise                 1.1.0                  r3.4.1_0    conda-forge
# r-network                 1.13.0.1         r341hc070d10_0    conda-forge
# r-pbdzmq                  0.3_2                  r3.4.1_0    conda-forge
# r-pillar                  1.2.2            r341h6115d3f_1    conda-forge
# r-pkgconfig               2.0.1                  r3.4.1_0    conda-forge
# r-plogr                   0.2.0            r341h6115d3f_0    conda-forge
# r-prettyunits             1.0.2                  r3.4.1_0    conda-forge
# r-purrr                   0.2.4            r341h470a237_1    conda-forge
# r-r6                      2.2.2                  r3.4.1_0    conda-forge
# r-rcpp                    0.12.17          r341h9d2a408_1    conda-forge
# r-repr                    0.15                     r341_0    conda-forge
# r-rlang                   0.2.1            r341h470a237_1    conda-forge
# r-rsqlite                 2.0              r341hfc679d8_1    conda-forge
# r-stringi                 1.2.3            r341hfc679d8_1    conda-forge
# r-stringr                 1.3.1                    r341_0    conda-forge
# r-tibble                  1.4.2            r341h470a237_1    conda-forge
# r-tidyselect              0.2.4            r341hfc679d8_1    conda-forge
# r-utf8                    1.1.3            r341h470a237_1    conda-forge
# r-uuid                    0.1_2                    r341_0    conda-forge
# ratelimiter               1.2.0                 py36_1000    conda-forge
# readline                  7.0                  haf1bffa_1    conda-forge
# requests                  2.13.0                   py36_0    conda-forge
# rpy2                      2.9.4           py36r341h24bf2e0_0    conda-forge
# rsa                       3.1.4                    py36_0    bioconda
# s3transfer                0.1.13                py36_1001    conda-forge
# samtools                  1.9                  h8ee4bcc_1    bioconda
# scikit-learn              0.19.1          py36_blas_openblas_201  [blas_openblas]  conda-forge
# scipy                     1.1.0           py36_blas_openblash7943236_201  [blas_openblas]  conda-forge
# seaborn                   0.9.0                      py_0    conda-forge
# send2trash                1.5.0                      py_0    conda-forge
# service_identity          17.0.0                     py_0    conda-forge
# setuptools                40.0.0                   py36_1    conda-forge
# simplegeneric             0.8.1                      py_1    conda-forge
# sip                       4.18.1           py36hfc679d8_0    conda-forge
# six                       1.11.0                   py36_1    conda-forge
# snakemake                 4.7.0                    py36_0    bioconda
# sqlite                    3.24.0               h2f33b56_0    conda-forge
# sra-tools                 2.9.1_1              h470a237_0    bioconda
# statsmodels               0.9.0            py36h7eb728f_0    conda-forge
# taxonkit                  0.2.4                         1    bioconda
# tbl2asn                   25.6                          3    bioconda
# terminado                 0.8.1                    py36_0    conda-forge
# testpath                  0.3.1                    py36_0    conda-forge
# tk                        8.6.8                         0    conda-forge
# tornado                   5.1              py36h470a237_1    conda-forge
# traitlets                 4.3.2                    py36_0    conda-forge
# twisted                   18.7.0           py36h14c3975_1
# tzlocal                   1.5.1                      py_0    conda-forge
# urllib3                   1.12                     py36_0    bioconda
# wcwidth                   0.1.7                      py_1    conda-forge
# webencodings              0.5                      py36_0    conda-forge
# wheel                     0.31.1                   py36_1    conda-forge
# wrapt                     1.10.11          py36h470a237_1    conda-forge
# xmlrunner                 1.7.7                      py_0    conda-forge
# xorg-kbproto              1.0.7                h470a237_2    conda-forge
# xorg-libice               1.0.9                h470a237_4    conda-forge
# xorg-libsm                1.2.2                h470a237_5    conda-forge
# xorg-libx11               1.6.5                h470a237_2    conda-forge
# xorg-libxau               1.0.8                h470a237_6    conda-forge
# xorg-libxdmcp             1.1.2                h470a237_7    conda-forge
# xorg-libxext              1.3.3                h470a237_4    conda-forge
# xorg-libxrender           0.9.10               h470a237_2    conda-forge
# xorg-libxt                1.1.5                h470a237_2    conda-forge
# xorg-renderproto          0.11.1               h470a237_2    conda-forge
# xorg-xextproto            7.3.0                h470a237_2    conda-forge
# xorg-xproto               7.0.31               h470a237_7    conda-forge
# xz                        5.2.4                h470a237_1    conda-forge
# yaml                      0.1.7                h470a237_1    conda-forge
# yarl                      1.3.0            py36h470a237_0    conda-forge
# zeromq                    4.2.5                hfc679d8_5    conda-forge
# zlib                      1.2.11               h470a237_3    conda-forge
# zope.interface            4.5.0            py36h470a237_0    conda-forge
