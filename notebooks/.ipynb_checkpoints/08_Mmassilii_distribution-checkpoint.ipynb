# %% [markdown]
# # Goal
# Jacobo de la Cuesta-Zuluaga.
#
# The aim of this notebook is to describe the abundance of members of *Methanomassiliicoccales* in different environments.

# %% [markdown]
# # Init

# %%
library(ggplot2)
library(tidyverse)
library(reshape2)
library(vegan)
library(cowplot)
library(caret)
library(forcats)
library(broom)
library(DESeq2)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ tibble  2.1.3     ✔ purrr   0.3.2
# ✔ tidyr   0.8.3     ✔ dplyr   0.8.3
# ✔ readr   1.3.1     ✔ stringr 1.4.0
# ✔ tibble  2.1.3     ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Attaching package: ‘reshape2’
#
# The following object is masked from ‘package:tidyr’:
#
#     smiths
#
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.5-5
#
# ********************************************************
# Note: As of version 1.0.0, cowplot does not change the
#   default ggplot2 theme anymore. To recover the previous
#   behavior, execute:
#   theme_set(theme_cowplot())
# ********************************************************
#
#
# Attaching package: ‘caret’
#
# The following object is masked from ‘package:vegan’:
#
#     tolerance
#
# The following object is masked from ‘package:purrr’:
#
#     lift
#
# Loading required package: S4Vectors
# Loading required package: stats4
# Loading required package: BiocGenerics
# Loading required package: parallel
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
# The following objects are masked from ‘package:dplyr’:
#
#     combine, intersect, setdiff, union
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colMeans,
#     colnames, colSums, dirname, do.call, duplicated, eval, evalq,
#     Filter, Find, get, grep, grepl, intersect, is.unsorted, lapply,
#     lengths, Map, mapply, match, mget, order, paste, pmax, pmax.int,
#     pmin, pmin.int, Position, rank, rbind, Reduce, rowMeans, rownames,
#     rowSums, sapply, setdiff, sort, table, tapply, union, unique,
#     unsplit, which, which.max, which.min
#
#
# Attaching package: ‘S4Vectors’
#
# The following objects are masked from ‘package:dplyr’:
#
#     first, rename
#
# The following object is masked from ‘package:tidyr’:
#
#     expand
#
# The following object is masked from ‘package:base’:
#
#     expand.grid
#
# Loading required package: IRanges
#
# Attaching package: ‘IRanges’
#
# The following objects are masked from ‘package:dplyr’:
#
#     collapse, desc, slice
#
# The following object is masked from ‘package:purrr’:
#
#     reduce
#
# Loading required package: GenomicRanges
# Loading required package: GenomeInfoDb
# Loading required package: SummarizedExperiment
# Loading required package: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
# Loading required package: DelayedArray
# Loading required package: matrixStats
#
# Attaching package: ‘matrixStats’
#
# The following objects are masked from ‘package:Biobase’:
#
#     anyMissing, rowMedians
#
# The following object is masked from ‘package:dplyr’:
#
#     count
#
# Loading required package: BiocParallel
#
# Attaching package: ‘DelayedArray’
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colMaxs, colMins, colRanges, rowMaxs, rowMins, rowRanges
#
# The following object is masked from ‘package:purrr’:
#
#     simplify
#
# The following objects are masked from ‘package:base’:
#
#     aperm, apply

# %%
# R util functions
source("/ebio/abt3_projects/vadinCA11/data/V11/R_utils/utils.R")

# %%
# Load itol scripts
itol_dir = "/ebio/abt3_projects/vadinCA11/data/V11/itol"
itol_code = file.path(itol_dir, "itol.R") 
source(file = itol_code)

# %% [markdown]
# # Var

# %%
distribution_dir = "/ebio/abt3_projects/vadinCA11/data/V11/Mmassilii_distribution/MGnify/"
metagenomes_dir = "/ebio/abt3_projects/databases_no-backup/MGnify/190900_dataset"

# KrakenUniq output dir
KrakenUniq_dir = file.path(distribution_dir, "krakenuniq")
KUniq_raw = file.path(KrakenUniq_dir, "report.tsv.gz") %>% 
    read_delim(delim = '\t')

# Metagenomes data
multiQC_raw = file.path(metagenomes_dir, "LLMGQC/reports/multiqc-final/multiqc_data/multiqc_fastqc.txt") %>% 
    read_delim(delim = '\t')

# Source of metagenomes
metadata_raw = file.path(metagenomes_dir, "MGnify_selected_metagenomes.tsv") %>%
    read_delim(delim = '\t')

# Mmassilii genomes information
Assemblies_table_raw = "/ebio/abt3_projects/vadinCA11/data/V11/genomes/included_table.txt" %>%
    read_delim(delim = '\t') %>%
    select(-1)

# Table of dereplicated genomes
dRep_table_raw = "/ebio/abt3_projects/vadinCA11/data/V11/drep/dereplication/data_tables/Cdb.csv" %>%
    read_csv()

plots_dir = "/ebio/abt3_projects/vadinCA11/data/V11/out_plots/"
# Out:
# Parsed with column specification:
# cols(
#   sample = col_character(),
#   perc = col_double(),
#   reads = col_double(),
#   taxReads = col_double(),
#   kmers = col_double(),
#   dup = col_double(),
#   cov = col_double(),
#   taxID = col_double(),
#   rank = col_character(),
#   taxName = col_character(),
#   taxName_full = col_character()
# )
# Parsed with column specification:
# cols(
#   .default = col_character(),
#   `Total Sequences` = col_double(),
#   `Sequences flagged as poor quality` = col_double(),
#   `%GC` = col_double(),
#   total_deduplicated_percentage = col_double(),
#   avg_sequence_length = col_double()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_character(),
#   host_tax_id = col_double(),
#   raw_seq_count = col_double(),
#   paired_reads = col_double(),
#   n = col_double(),
#   rand_sample = col_double(),
#   category = col_double()
# )
# See spec(...) for full column specifications.
# Warning message:
# “Missing column names filled in: 'X1' [1]”Parsed with column specification:
# cols(
#   X1 = col_double(),
#   Accession = col_character(),
#   Assembly = col_character(),
#   Organism = col_character()
# )
# Parsed with column specification:
# cols(
#   genome = col_character(),
#   secondary_cluster = col_character(),
#   threshold = col_double(),
#   cluster_method = col_character(),
#   comparison_algorithm = col_character(),
#   primary_cluster = col_double()
# )

# %%
# Clades of Methanomassilii
# Add Clade data to the metadata table and save
# Host Associated, Free Living and EXternal
HA_clade = c("GCA_002504405", "GCA_002506175", "GCA_002504495", "GCA_002506425", 
             "GCA_002503925", "GCA_002494805", "GCA_002498545", "GCA_002497475", 
             "GCA_002508595", "GCA_000800805", "GCA_002506905", "GCA_002496945", 
             "GCA_002495325", "GCA_002503545", "GCA_000300255", "V11_RL001", 
             "GCA_001481295", "GCA_900313075", "GCA_900314325", "GCA_002505245", 
             "GCA_002503785", "GCA_002506865", "GCA_002502545", "GCA_002509415", 
             "GCA_002498765", "GCA_002498785", "GCA_001421175", "GCA_002502965", 
             "GCA_002497155", "GCA_002509425", "GCA_002496785", "GCA_002505275", 
             "GCA_002506325", "GCA_002498605", "GCA_002509405", "GCA_002505345", 
             "GCA_002504645", "GCA_002502765", "GCA_002495665", "GCA_002506565", 
             "GCA_002508625", "GCA_002498425", "GCA_002498805", "GCA_002502925", 
             "GCA_002502465", "GCA_002498365", "GCA_002506995", "GCA_002494585", 
             "GCA_002509465", "GCA_002495495")

FL_clade = c("GCA_003153895", "GCA_003135935", "GCA_002506985", "GCA_002497075", 
             "GCA_000404225", "GCA_000308215", "GCA_002508545", "GCA_002494705", 
             "GCA_001421185", "GCA_002498285", "GCA_002495585", "GCA_002497995", 
             "GCA_002504525", "GCA_002496345", "GCA_002508585", "GCA_002508555", 
             "GCA_002502005", "GCA_002503495", "GCA_002505225", "GCA_002503645")

EX_clade = c("GCA_002496385", "GCA_002499085")

df_HA = data.frame(Assembly = HA_clade, Clade = rep("HA", length(HA_clade)))
df_FL = data.frame(Assembly = FL_clade, Clade = rep("FL", length(FL_clade)))
df_EX = data.frame(Assembly = EX_clade, Clade = rep("EX", length(EX_clade)))

df_Clade = bind_rows(df_HA, df_FL, df_EX) %>% 
    mutate(Clade = factor(Clade))

Assemblies_table = Assemblies_table_raw %>%
    select(-Assembly) %>%
    mutate(Organism = str_replace_all(Organism, " ", "_"), 
           Organism = str_remove_all(Organism, "\\."),
           Organism = str_replace_all(Organism, "-", "_"),
           Accession = str_remove(Accession, pattern = "\\.[:digit:]")) %>%
    rename("Accession" = "Assembly")

Assemblies_table = left_join(df_Clade, Assemblies_table) %>% 
    rename("Organism" = "Taxonomy") %>%
    arrange(Clade, Taxonomy)

Assemblies_table[Assemblies_table$Assembly == "V11_RL001", "Taxonomy"] = "Candidatus_Methanomethylophilus_alvus_RL001"
# Out:
# Warning message in bind_rows_(x, .id):
# “Unequal factor levels: coercing to character”Warning message in bind_rows_(x, .id):
# “binding character and factor vector, coercing into character vector”Warning message in bind_rows_(x, .id):
# “binding character and factor vector, coercing into character vector”Warning message in bind_rows_(x, .id):
# “Unequal factor levels: coercing to character”Warning message in bind_rows_(x, .id):
# “binding character and factor vector, coercing into character vector”Warning message in bind_rows_(x, .id):
# “binding character and factor vector, coercing into character vector”Warning message in bind_rows_(x, .id):
# “binding character and factor vector, coercing into character vector”Warning message in bind_rows_(x, .id):
# “binding character and factor vector, coercing into character vector”Joining, by = "Assembly"

# %% [markdown]
# # Organize tables

# %% [markdown]
# ## MultiQC of metagenomes

# %%
# Retain only R1
multiQC = multiQC_raw %>% 
    filter(Filename == "R1_final.fq.gz") %>%
    select(Sample, Sequences = "Total Sequences")
# Fix sample names
multiQC = multiQC %>% 
    pull(Sample) %>% 
    str_replace(fixed(" | fastqc_per_sample | R1_final"), "") %>%
    mutate(.data = multiQC, Sample = .)

sample_order = multiQC %>% 
    pull(Sample)

multiQC %>% dfhead
# Out:
# [1] 313   2
#   Sample    Sequences
# 1 DRS034400 88844958
# 2 DRS034401 89593137
# 3 DRS034402 73790577

# %% [markdown]
# ## KrakenUniq tables

# %% [markdown]
# ## Environment information

# %%
# Prepare metadata table
# Filter metagenomes from wastewater and hospital biofilms

wastewater_ids = metadata_raw %>% 
    filter(biome_1 == "Engineered") %>% 
    pull(id) %>%
    as.character()

hospital_ids = metadata_raw %>%
    filter(biome_4 == "Drinking water") %>% 
    pull(id)

metadata = metadata_raw %>%
    filter(!(id %in% c(wastewater_ids, hospital_ids))) %>%
    select(id, starts_with("environment"), starts_with("biome")) %>% 
    mutate_all(.funs = c(factor))

# %%
# Keep data at assembly level, filter by kmer number and fix names
KUniq_relabund_raw = KUniq_raw %>%
    filter(rank == "assembly") %>%
    mutate(perc = case_when(kmers < 100 ~ 0, TRUE ~ as.numeric(perc))) %>%
    mutate(Accession = str_replace(taxName, "_[:digit:]$", "")) %>%
    mutate(Accession = str_replace_all(Accession, " ", "")) %>%
    select(sample, Accession, perc, reads) 

# Wide format
KUniq_relabund = KUniq_relabund_raw %>%
    select(sample, perc, Accession) %>%
    spread(sample, perc)

# Replace NAs for 0
KUniq_relabund[is.na(KUniq_relabund)] = 0

KUniq_relabund[is.na(KUniq_relabund)] = 0

# Remove wastewater samples, retain GIT and environmental samples
KUniq_relabund = KUniq_relabund %>% 
    left_join(df_Clade, by = c("Accession" = "Assembly")) %>%
    select(-one_of(c(wastewater_ids, hospital_ids)))

# %% [markdown]
# # KrakenUniq

# %%
# Mean abundance of each clade in each metagenome
Mean_clade_env = KUniq_relabund %>%
    select(-Accession) %>%
    group_by(Clade) %>%
    summarise_if(is.numeric, ~ mean(.))

# %%
# Obtain sum of all taxa in each clade in each sample
Sum_clade_env = KUniq_relabund %>%
    select(-Accession) %>%
    group_by(Clade) %>%
    summarise_if(is.numeric, list(sum)) %>% 
    t %>%
    as.data.frame %>%
    rownames_to_column()
    
colnames(Sum_clade_env) = c("Sample","EX","FL","HA")
Sum_clade_env = Sum_clade_env[-1,]
Sum_clade_env %>% dfhead
# Out:
# [1] 305   4
#   Sample     EX        FL        HA
# 2 ERS1030529 0.000000  0.008347  0.000000
# 3 ERS1030531 0.000000  0.003366  0.000000
# 4 ERS1030532 0.0000000 0.0048847 0.0000000

# %%
# Add source information
Sum_clade_source = left_join(Sum_clade_env, metadata, by = c("Sample" = "id")) %>%
    select(Sample, EX, FL, HA, Env = biome_4) %>%
    gather(Clade, Abundance, -c(Env, Sample)) %>%
    mutate(Abundance = as.numeric(Abundance)) %>%
    distinct()

Sum_clade_source %>% dfhead
# Out:
# Warning message:
# “Column `Sample`/`id` joining character vector and factor, coercing into character vector”Warning message:
# “attributes are not identical across measure variables;
# they will be dropped”
# [1] 915   4
#   Sample     Env Clade Abundance
# 1 ERS1030529 Ice EX    0
# 2 ERS1030531 Ice EX    0
# 3 ERS1030532 Ice EX    0

# %%
# Mean abundance of each clade on each environment
mean_clade_source = Sum_clade_source %>% 
    group_by(Env, Clade) %>%
    summarise(mean = mean(Abundance), sd = sd(Abundance)) %>%
    arrange(Env, -mean)

mean_clade_source
# Out:
#    Env             Clade mean         sd
# 1  Coastal         FL    3.741121e-03 4.839059e-03
# 2  Coastal         HA    8.004893e-04 1.666619e-03
# 3  Coastal         EX    4.004750e-04 5.025856e-04
# 4  Desert          FL    1.839585e-02 1.161239e-03
# 5  Desert          HA    6.769795e-03 5.413107e-04
# 6  Desert          EX    1.507725e-03 1.502368e-04
# 7  Fecal           HA    2.109210e-02 3.913065e-02
# 8  Fecal           FL    8.499541e-03 1.098166e-02
# 9  Fecal           EX    3.201409e-04 5.485330e-04
# 10 Foregut         HA    1.864217e-05 6.090698e-05
# 11 Foregut         EX    0.000000e+00 0.000000e+00
# 12 Foregut         FL    0.000000e+00 0.000000e+00
# 13 Grasslands      FL    1.768774e-02 8.729414e-04
# 14 Grasslands      HA    7.992860e-03 1.920217e-03
# 15 Grasslands      EX    1.503737e-03 1.602207e-04
# 16 Groundwater     FL    1.009533e-03 1.748563e-03
# 17 Groundwater     EX    0.000000e+00 0.000000e+00
# 18 Groundwater     HA    0.000000e+00 0.000000e+00
# 19 Hypersaline     FL    1.978858e-02 1.101297e-02
# 20 Hypersaline     HA    1.870644e-03 2.242926e-03
# 21 Hypersaline     EX    0.000000e+00 0.000000e+00
# 22 Ice             FL    5.377930e-03 2.097911e-03
# 23 Ice             HA    8.290000e-05 2.621528e-04
# 24 Ice             EX    0.000000e+00 0.000000e+00
# 25 Intertidal zone HA    1.671628e-02 1.446238e-02
# 26 Intertidal zone FL    1.374888e-02 7.510203e-03
# 27 Intertidal zone EX    1.458608e-03 8.760832e-04
# 28 Large intestine HA    1.434254e-02 2.956863e-02
# 29 Large intestine FL    1.044361e-02 2.034294e-02
# 30 Large intestine EX    6.228636e-05 2.380501e-04
# 31 Lentic          FL    4.087000e-04 4.027389e-04
# 32 Lentic          HA    9.976667e-06 1.993202e-05
# 33 Lentic          EX    0.000000e+00 0.000000e+00
# 34 Permafrost      FL    1.027900e-02 4.551117e-03
# 35 Permafrost      HA    3.193742e-03 1.420694e-03
# 36 Permafrost      EX    8.249036e-04 3.528481e-04
# 37 Saline          FL    2.410145e-02 1.089220e-02
# 38 Saline          HA    5.271450e-03 1.490652e-03
# 39 Saline          EX    1.784550e-03 6.526596e-05
# 40 Sand            FL    9.030008e-03 2.641006e-03
# 41 Sand            HA    1.866950e-03 6.438317e-04
# 42 Sand            EX    6.763750e-04 4.232204e-04
# 43 Sediment        FL    1.210160e-02 9.319355e-03
# 44 Sediment        HA    2.023135e-03 2.942979e-03
# 45 Sediment        EX    1.609145e-03 2.130485e-03
# 46 Stomach         HA    1.603428e-02 9.885792e-03
# 47 Stomach         FL    6.095534e-03 2.586493e-03
# 48 Stomach         EX    9.409667e-04 5.944461e-04

# %%
# Plot the abundance of each clade on each environment
options(repr.plot.width = 7, repr.plot.height = 7)

# Colors
clades_pallete = c("#7f7db9", "#15a783",  "#e16f0b")

# Order of facets
Envs_order = c("Stomach", "Foregut", "Large intestine", "Fecal",
               "Desert", "Sand", "Grasslands","Permafrost", "Sediment",
               "Coastal", "Intertidal zone", "Lentic", "Groundwater",
               "Saline", "Hypersaline", "Ice")

plt_distribution_df = Sum_clade_source %>% 
    mutate(Env = (str_remove_all(Env, "\\(anaerobic\\)")), 
           Env = fct_relevel(Env, Envs_order))

# Note change in clade name
plt_distribution = plt_distribution_df %>%
    ggplot(., aes(x = Clade, y = Abundance, color  = Clade)) +
    geom_jitter(alpha = 0.5, position = position_jitter(width = 0.2, height = 0)) +
    facet_wrap(~Env, nrow = 4) +
    scale_y_log10(breaks = scales::trans_breaks("log10", function(x) 10^x), 
                labels = scales::trans_format("log10", scales::math_format(10^.x))) +
    labs(y = "Abundance (%)") +
    scale_color_manual(values = clades_pallete) +
    theme_light() +
    theme(legend.position="none", 
          panel.grid.major = element_blank(), 
          panel.grid.minor = element_blank()) +
    stat_summary(fun.y = mean, 
                 fun.ymin = function(x) mean(x) - sd(x), 
                 fun.ymax = function(x) mean(x) + sd(x), 
                 geom = "pointrange", colour = "black", size = 0.2)
plot(plt_distribution)
# Out:
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 338 rows containing non-finite values (stat_summary).”Warning message:
# “Removed 2 rows containing missing values (geom_pointrange).”
# plot without title

# %%
plot_file = file.path(plots_dir, "Mmassilii_distribution.png")
save_plot(filename = plot_file, plot = plt_distribution,
          base_height = 7, base_width = 7, dpi = 300)
# Out:
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 338 rows containing non-finite values (stat_summary).”Warning message:
# “Removed 2 rows containing missing values (geom_pointrange).”

# %%
options(repr.plot.width = 8, repr.plot.height = 4)

plt = ggplot(plt_distribution_df, aes(x = Env, y = Abundance, color = Clade)) +
    geom_jitter(alpha = 0.7, position = position_jitterdodge(dodge.width = 0.8, jitter.width = 0.05)) +
    theme_light() +
    scale_color_manual(values = clades_pallete) +
    theme(axis.text.x = element_text(angle = 45, hjust = 1)) +
    labs(x = "Environment", y = "Abundance (%)")
    
plot(plt)
# Out:
# plot without title

# %% [markdown]
# ## Summaries

# %%
# Add source information
Sum_clade_b = left_join(Sum_clade_env, metadata, by = c("Sample" = "id")) %>%
    select(Sample, EX, FL, HA, Env = biome_4) %>%
    gather(Clade, Abundance, -c(Env, Sample)) %>%
    mutate(Abundance = as.numeric(Abundance)) %>%
    distinct()

Sum_clade_b %>% dfhead

# Mean abundance of each clade on each environment
mean_clade_b = Sum_clade_b %>% 
    group_by(Env, Clade) %>%
    summarise(mean = mean(Abundance), sd = sd(Abundance)) %>%
    arrange(Env, -mean)

mean_clade_b %>% 
    mutate_if(is.numeric, round, 4) %>%
    arrange(Clade)
# Out:
# Warning message:
# “Column `Sample`/`id` joining character vector and factor, coercing into character vector”Warning message:
# “attributes are not identical across measure variables;
# they will be dropped”
# [1] 915   4
#   Sample     Env Clade Abundance
# 1 ERS1030529 Ice EX    0
# 2 ERS1030531 Ice EX    0
# 3 ERS1030532 Ice EX    0
# `mutate_if()` ignored the following grouping variables:
# Column `Env`
#    Env             Clade mean   sd
# 1  Coastal         EX    0.0004 0.0005
# 2  Desert          EX    0.0015 0.0002
# 3  Fecal           EX    0.0003 0.0005
# 4  Foregut         EX    0.0000 0.0000
# 5  Grasslands      EX    0.0015 0.0002
# 6  Groundwater     EX    0.0000 0.0000
# 7  Hypersaline     EX    0.0000 0.0000
# 8  Ice             EX    0.0000 0.0000
# 9  Intertidal zone EX    0.0015 0.0009
# 10 Large intestine EX    0.0001 0.0002
# 11 Lentic          EX    0.0000 0.0000
# 12 Permafrost      EX    0.0008 0.0004
# 13 Saline          EX    0.0018 0.0001
# 14 Sand            EX    0.0007 0.0004
# 15 Sediment        EX    0.0016 0.0021
# 16 Stomach         EX    0.0009 0.0006
# 17 Coastal         FL    0.0037 0.0048
# 18 Desert          FL    0.0184 0.0012
# 19 Fecal           FL    0.0085 0.0110
# 20 Foregut         FL    0.0000 0.0000
# 21 Grasslands      FL    0.0177 0.0009
# 22 Groundwater     FL    0.0010 0.0017
# 23 Hypersaline     FL    0.0198 0.0110
# 24 Ice             FL    0.0054 0.0021
# 25 Intertidal zone FL    0.0137 0.0075
# 26 Large intestine FL    0.0104 0.0203
# 27 Lentic          FL    0.0004 0.0004
# 28 Permafrost      FL    0.0103 0.0046
# 29 Saline          FL    0.0241 0.0109
# 30 Sand            FL    0.0090 0.0026
# 31 Sediment        FL    0.0121 0.0093
# 32 Stomach         FL    0.0061 0.0026
# 33 Coastal         HA    0.0008 0.0017
# 34 Desert          HA    0.0068 0.0005
# 35 Fecal           HA    0.0211 0.0391
# 36 Foregut         HA    0.0000 0.0001
# 37 Grasslands      HA    0.0080 0.0019
# 38 Groundwater     HA    0.0000 0.0000
# 39 Hypersaline     HA    0.0019 0.0022
# 40 Ice             HA    0.0001 0.0003
# 41 Intertidal zone HA    0.0167 0.0145
# 42 Large intestine HA    0.0143 0.0296
# 43 Lentic          HA    0.0000 0.0000
# 44 Permafrost      HA    0.0032 0.0014
# 45 Saline          HA    0.0053 0.0015
# 46 Sand            HA    0.0019 0.0006
# 47 Sediment        HA    0.0020 0.0029
# 48 Stomach         HA    0.0160 0.0099

# %% [markdown]
# ### Mean of each clade in gut/environmental biomes

# %%
# Categorize metagenome samples as Gut or nonGut (i.e. environmental)
gut_envs = c("Fecal", "Foregut", "Large intestine","Stomach")


Sum_clade_source %>%
    mutate(Env_binary = ifelse(Env %in% gut_envs, "Gut", "nonGut")) %>%
    group_by(Clade, Env_binary) %>%
    summarise(mean = mean(Abundance, na.rm = T), 
              sd = sd(Abundance, na.rm = T)) %>%
    mutate_if(is.numeric, function(x) round(x, 4))
# Out:
# `mutate_if()` ignored the following grouping variables:
# Column `Clade`
#   Clade Env_binary mean   sd
# 1 EX    Gut        0.0002 0.0005
# 2 EX    nonGut     0.0009 0.0012
# 3 FL    Gut        0.0078 0.0154
# 4 FL    nonGut     0.0104 0.0083
# 5 HA    Gut        0.0143 0.0301
# 6 HA    nonGut     0.0045 0.0081

# %%
metadata_DESeq = metadata %>% 
    mutate(Env_binary = ifelse(biome_4 %in% gut_envs, "Gut", "nonGut")) %>%
    select(id, Env_binary) %>%
    filter(id != "SRS429585") %>%
    distinct %>% 
    column_to_rownames("id")

# %% [markdown]
# ## Abundance of each taxon in each environment

# %%
# Function to obtain mean abundance of taxa in each environment
taxa_mean = function(abundance_table, environment, metadata, biome_var){
  
    Env_metagenomes = metadata %>% 
        filter({{ biome_var }} == environment) %>%
        pull(id) %>%
        as.vector()

    Env_mean = abundance_table %>% 
        select(one_of(Env_metagenomes)) %>%
        rowMeans

    Env_mean    
}

# %%
# Range of individual genomes across all samples
KUniq_relabund %>% 
    select(-Accession, -Clade) %>%
    map_dbl(function(x) max(x, na.rm = TRUE)) %>%
    min()

KUniq_relabund %>% 
    select(-Accession, -Clade) %>%
    map_dbl(function(x) max(x, na.rm = TRUE)) %>%
    max()
# Out:
# [1] 0
# [1] 0.1453

# %%
# Filter metagenomes metadata table to retain only samples with abundance data
present_samples = KUniq_relabund %>%
    select(-Accession, -Clade) %>%
    colnames()

filt_metadata = metadata %>%
    filter(id %in% present_samples)

Environments = metadata %>% 
    pull(biome_1) %>% 
    unique()

Tax_env_mean_1 = map(Environments, function(x) taxa_mean(KUniq_relabund, x, filt_metadata, biome_1)) %>%
    set_names(., Environments) %>%
    as.data.frame()     
                   
Tax_env_mean_1 = bind_cols(Taxon = KUniq_relabund$Accession, Tax_env_mean_1) %>%
    gather(Environment, Abundance, -c(Taxon))
                     
Tax_env_mean_1 %>% 
    group_by(Environment) %>% 
    summarise(min = min(Abundance), max = max(Abundance))
# Out:
#   Environment     min          max
# 1 Environmental   3.397125e-06 0.002237551
# 2 Host.associated 1.769655e-06 0.008387321

# %%
# Filter metagenomes metadata table to retain only samples with abundance data
present_samples = KUniq_relabund %>%
    select(-Accession, -Clade) %>%
    colnames()

filt_metadata = metadata %>%
    filter(id %in% present_samples)


Environments = metadata %>% 
    pull(biome_4) %>% 
    unique()

Tax_env_mean = map(Environments, function(x) taxa_mean(KUniq_relabund, x, filt_metadata, biome_4)) %>%
    set_names(., Environments) %>%
    as.data.frame()     
                   
Tax_env_mean = bind_cols(Taxon = KUniq_relabund$Accession, Tax_env_mean) %>%
    gather(Environment, Abundance, -c(Taxon))
Tax_env_mean %>% dfhead
# Out:
# [1] 464   3
#   Taxon         Environment     Abundance
# 1 GCA_000308215 Large.intestine 1.117073e-03
# 2 GCA_000404225 Large.intestine 7.813636e-06
# 3 GCA_000800805 Large.intestine 6.025758e-05

# %%
# Long format and add envinronment and clade data
# Reorder levels of Taxon for plot

metagenomes_biome4 = metadata %>%
    select(id, biome_4) %>%
    filter(!duplicated(.))

Tax_per_samp = KUniq_relabund %>%
    select(-Clade) %>%
    gather(Sample, Abundance, -Accession) %>%
    left_join(., metagenomes_biome4, by = c("Sample" = "id")) %>%
    left_join(., Assemblies_table, by = c("Accession" = "Assembly"))

Tax_per_samp %>% dfhead
# Out:
# Warning message:
# “Column `Sample`/`id` joining character vector and factor, coercing into character vector”
# [1] 8845    6
#   Accession     Sample     Abundance biome_4 Clade
# 1 GCA_000308215 ERS1030529 0.001279  Ice     FL
# 2 GCA_000404225 ERS1030529 0.000000  Ice     FL
# 3 GCA_000800805 ERS1030529 0.000000  Ice     HA
#   Taxonomy
# 1 Methanomassiliicoccus_luminyensis_B10
# 2 Candidatus_Methanomassiliicoccus_intestinalis_Issoire_Mx1
# 3 Candidatus_Methanoplasma_termitum

# %%
plt_fun = function(environment, abundance_table){
    clades_pallete = c("#7f7db9", "#15a783", "#e16f0b")
    
    plt = abundance_table %>% 
    filter(biome_4 == environment) %>%
    #arrange(Clade) %>%
    ggplot(., aes(x = Taxonomy, y = Abundance, color = Clade)) +
        geom_jitter(alpha = 0.7, position = position_jitter(width = 0.2, height = 0))  + 
        scale_y_log10(breaks = scales::trans_breaks("log10", function(x) 10^x), 
                labels = scales::trans_format("log10", scales::math_format(10^.x))) +
        theme_light() +
        scale_color_manual(values = clades_pallete) +
        theme(panel.grid.major = element_blank(), 
              panel.grid.minor = element_blank(), 
              axis.text.x = element_text(angle = 45, hjust = 1),
              legend.position = "none") +
        labs(x = "Taxon", y = "Abundance (%)", title = environment) +
        stat_summary(fun.data=mean_sdl, fun.args = list(mult=1), 
                     geom="pointrange", color="black", size = 0.2) +
        coord_flip()
}

# envs_vector = metadata %>%
#     pull(biome_4) %>%
#     levels

Tax_per_samp = Tax_per_samp %>% 
    mutate(Taxonomy = str_remove(Taxonomy, "uncultured")) %>%
    arrange(Clade, Taxonomy) %>% 
    mutate(Taxonomy = factor(Taxonomy),
           Taxonomy = str_replace_all(Taxonomy, "_", " "),
           Taxonomy = fct_inorder(Taxonomy))

plots_environment = map(Envs_order, function(x) plt_fun(x, Tax_per_samp))

# %%
options(repr.plot.width = 20, repr.plot.height =  length(plots_environment))
Mmassilii_genomes_distribution = plot_grid(plotlist = plots_environment, ncol = 4)
Mmassilii_genomes_distribution

plot_file = file.path(plots_dir, "Mmassilii_genomes_distribution.png")
save_plot(filename = plot_file, plot = Mmassilii_genomes_distribution,
          base_height = 20, base_width = 1.2*length(plots_environment), dpi = 300)
# Out:
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 77 rows containing non-finite values (stat_summary).”Warning message:
# “Removed 1 rows containing missing values (geom_pointrange).”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 663 rows containing non-finite values (stat_summary).”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 1327 rows containing non-finite values (stat_summary).”Warning message:
# “Removed 2 rows containing missing values (geom_pointrange).”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 791 rows containing non-finite values (stat_summary).”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 23 rows containing non-finite values (stat_summary).”Warning message:
# “Removed 1 rows containing missing values (geom_pointrange).”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 199 rows containing non-finite values (stat_summary).”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 35 rows containing non-finite values (stat_summary).”Warning message:
# “Removed 1 rows containing missing values (geom_pointrange).”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 209 rows containing non-finite values (stat_summary).”Warning message:
# “Removed 2 rows containing missing values (geom_pointrange).”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 584 rows containing non-finite values (stat_summary).”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 662 rows containing non-finite values (stat_summary).”Warning message:
# “Removed 1 rows containing missing values (geom_pointrange).”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 181 rows containing non-finite values (stat_summary).”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 164 rows containing non-finite values (stat_summary).”Warning message:
# “Removed 4 rows containing missing values (geom_pointrange).”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 83 rows containing non-finite values (stat_summary).”Warning message:
# “Removed 4 rows containing missing values (geom_pointrange).”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 21 rows containing non-finite values (stat_summary).”Warning message:
# “Removed 1 rows containing missing values (geom_pointrange).”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 195 rows containing non-finite values (stat_summary).”Warning message:
# “Removed 2 rows containing missing values (geom_pointrange).”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 256 rows containing non-finite values (stat_summary).”Warning message:
# “Removed 2 rows containing missing values (geom_pointrange).”
# plot without title

# %% [markdown]
# ## Tables

# %%
# Number of samples per environment
Sum_clade_source %>% 
    group_by(Env, Clade) %>% 
    filter(Clade == "HA") %>%
    summarise(n = n())
# Out:
#    Env             Clade n
# 1  Coastal         HA    28
# 2  Desert          HA     4
# 3  Fecal           HA    44
# 4  Foregut         HA    23
# 5  Grasslands      HA     8
# 6  Groundwater     HA     3
# 7  Hypersaline     HA     9
# 8  Ice             HA    10
# 9  Intertidal zone HA    25
# 10 Large intestine HA    66
# 11 Lentic          HA     6
# 12 Permafrost      HA    22
# 13 Saline          HA     2
# 14 Sand            HA    12
# 15 Sediment        HA    31
# 16 Stomach         HA    12

# %%
# Mean and SD of clade by environment
Mean_clade_source = Sum_clade_source %>% 
    group_by(Env, Clade) %>% 
    summarise(mean_abund = round(mean(Abundance), 4), sd = round(sd(Abundance), 4))  %>%
    arrange(Clade, -mean_abund)

Mean_clade_source %>% dfhead
# Out:
# [1] 48  4
#   Env      Clade mean_abund sd
# 1 Saline   EX    0.0018     0.0001
# 2 Sediment EX    0.0016     0.0021
# 3 Desert   EX    0.0015     0.0002

# %% [markdown]
# # DESeq2

# %%
# Create table of sequence counts for Use in DESeq
# Observations with < 100 unique kmers are considered 0
KUniq_DESeq = KUniq_raw %>%
    filter(rank == "assembly") %>%
    mutate(reads = case_when(kmers < 100 ~ 0, TRUE ~ as.numeric(reads))) %>%
    mutate(Accession = str_replace(taxName, "_[:digit:]$", "")) %>%
    mutate(Accession = str_replace_all(Accession, " ", "")) %>%
    select(sample, Accession, reads) 

# Remove metagenome samples from anthropogenic samples
KUniq_DESeq = KUniq_DESeq %>% 
    filter(sample %in% metadata$id) %>%
    spread(sample, reads) %>%
    column_to_rownames("Accession")

# Add 1 to each count so DESeq can run
KUniq_DESeq[is.na(KUniq_DESeq)] = 0
KUniq_DESeq = KUniq_DESeq + 1

# %%
# Categorize metagenome samples as Gut or nonGut (i.e. environmental)
gut_envs = c("Fecal", "Foregut", "Large intestine","Stomach")

metadata_DESeq = metadata %>% 
    mutate(Env_binary = ifelse(biome_4 %in% gut_envs, "Gut", "nonGut")) %>%
    select(id, Env_binary) %>%
    filter(id != "SRS429585") %>%
    distinct %>% 
    column_to_rownames("id")

KUniq_DESeq = KUniq_DESeq[, rownames(metadata_DESeq)]

KUniq_DESeq %>% dfhead
metadata_DESeq %>% dfhead
# Out:
# [1]  29 305
#               ERS723591 ERS723612 ERS723614 ERS723595 ERS723671 ERS723593
# GCA_000308215 1         1         1         1         1         1
# GCA_000404225 1         1         1         1         1         1
# GCA_000800805 1         1         1         1         1         1
#               ERS723663 ERS723676 ERS723606 ERS723624 ⋯ ERS970416 ERS2085267
# GCA_000308215 1346      2123      1         1         ⋯ 66        146
# GCA_000404225    1         1      1         1         ⋯  1          1
# GCA_000800805    1         1      1         1         ⋯ 23        355
#               ERS2085081 ERS2085419 ERS970200 ERS2085357 ERS970227 ERS970396
# GCA_000308215 276        77         751       166        82        206
# GCA_000404225   1         1           1         1         1          1
# GCA_000800805 420         1          36        65        80          1
#               ERS970222 ERS970335
# GCA_000308215 543       264
# GCA_000404225   1         1
# GCA_000800805  26        64
# [1] 305   1
#           Env_binary
# ERS723591 Gut
# ERS723612 Gut
# ERS723614 Gut

# %%
# Run DESeq to determine taxa enriched in gut compared to nonGut environments
dds = DESeqDataSetFromMatrix(countData = KUniq_DESeq,
                              colData = metadata_DESeq,
                              design = ~ Env_binary)

dds = DESeq(dds, fitType = "mean")
dds_results = results(dds)
# Out:
# converting counts to integer mode
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 10 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing

# %%
# Results to data frame
dds_table = dds_results %>% 
    as.data.frame %>%
    rownames_to_column("Accession")

# Join DESeq results with assembly data
dds_table = left_join(dds_table, Assemblies_table, by = c("Accession" = "Assembly")) %>%
    arrange(log2FoldChange) %>%
    mutate(significant = if_else(padj <= 0.1, TRUE, FALSE))

# %%
dRep_table = dRep_table_raw %>%
    select(Accession = genome, Cluster = secondary_cluster) %>%
    mutate(Accession = str_remove(Accession, "\\..*"))

# %%
# Join GE ratio of representatives with dereplication table
# Replace NAs for the mean abund and GE ratio of representative of cluster

GE_ratio_DESeq = full_join(dRep_table, dds_table, by = "Accession") %>%
    mutate(Rep_genome = ifelse(is.na(log2FoldChange), F, T)) %>%
    group_by(Cluster) %>%
    do(arrange(., -Rep_genome) %>% 
       mutate(log2FoldChange = .$log2FoldChange[1], 
              padj = .$padj[1], 
              significant = .$significant[1])) %>%
    ungroup() %>%
    select(Accession, log2FoldChange, padj, significant) 

# Reorder factors for plotting
GE_ratio_DESeq = full_join(GE_ratio_DESeq, Assemblies_table, by = c("Accession" = "Assembly")) %>%
    arrange(log2FoldChange) %>%
    mutate(Accession = fct_inorder(Accession), Taxonomy = fct_inorder(Taxonomy))

# %%
# Taxa with log2 fold change opposite to the expected given their clade
GE_ratio_DESeq %>% filter(Clade == "FL", log2FoldChange < 0)
GE_ratio_DESeq %>% filter(Clade == "HA", log2FoldChange > 0)
# Out:
#   Accession     log2FoldChange padj         significant Clade
# 1 GCA_001421185 -3.6098934     7.745669e-40  TRUE       FL
# 2 GCA_002508545 -0.9977002     8.689222e-05  TRUE       FL
# 3 GCA_000404225 -0.5015206     8.516560e-02  TRUE       FL
# 4 GCA_000308215 -0.1212717     6.655059e-01 FALSE       FL
#   Taxonomy
# 1 Methanomassiliicoccales_archaeon_RumEn_M1
# 2 Methanomassiliicoccus_sp_UBA6
# 3 Candidatus_Methanomassiliicoccus_intestinalis_Issoire_Mx1
# 4 Methanomassiliicoccus_luminyensis_B10
#   Accession     log2FoldChange padj         significant Clade
# 1 GCA_000800805 1.326174       8.537341e-07 TRUE        HA
#   Taxonomy
# 1 Candidatus_Methanoplasma_termitum

# %% [markdown]
# ## Export tables and ITOL files

# %%
# Save ITOL bar chart
GE_ratio_DESeq %>%
    column_to_rownames("Accession") %>%
    select(log2FoldChange) %>%
    itol_simplebar(df = ., dataset_label = "Fold_Change", 
                    out_file = "DESeq_simplebar.txt", out_dir =  itol_dir)
# Out:
# File written: /ebio/abt3_projects/vadinCA11/data/V11/itol/DESeq_simplebar.txt

# %%
# Save ITOL significance
GE_ratio_DESeq %>%
    mutate(significant = if_else(significant == TRUE, 1, 0)) %>%
    column_to_rownames("Accession") %>%
    select(significant) %>%
    itol_externalshape(df = ., dataset_label = "Enrichment_Significance", 
                    out_file = "DESeq_externalshape.txt", out_dir =  itol_dir)
# Out:
# File written: /ebio/abt3_projects/vadinCA11/data/V11/itol/DESeq_externalshape.txt

# %%
# Environment enrichment in a single color strip summary
GE_ratio_DESeq %>%
    mutate(simple_enrich = case_when((log2FoldChange > 0 & significant == T) ~ "Environmental",
                                     (log2FoldChange < 0 & significant == T) ~ "Gut", 
                                     TRUE ~ "Non-significant")) %>%
    column_to_rownames("Accession") %>%
    select(simple_enrich) %>%
    itol_colorstrip(df = ., dataset_label = "Enrichment_summary", 
                    out_file = "simple_enrich_colorstrip.txt", out_dir =  itol_dir)
# Out:
# File written: /ebio/abt3_projects/vadinCA11/data/V11/itol/simple_enrich_colorstrip.txt

# %%
# Export DESeq simple enrichment table
Simple_enrich_df = GE_ratio_DESeq %>%
    mutate(simple_enrich = case_when((log2FoldChange > 0 & significant == T) ~ "Environmental",
                                     (log2FoldChange < 0 & significant == T) ~ "Gut", 
                                   TRUE ~ "Non-significant")) 

write_tsv(Simple_enrich_df, "/ebio/abt3_projects/vadinCA11/data/V11/Mmassilii_distribution/Enrichment/Simple_Enrich.tsv")

# %% [markdown]
# ## Unsupervised clustering of Log fold change

# %%
library(ape)
# Load phylogenomic tree
#phylo_tree_file = file.path("/ebio/abt3_projects/vadinCA11/data/V11/anvio_output/phylogenomic_tree.txt")
phylo_tree_file = file.path("/ebio/abt3_projects/vadinCA11/data/V11/phylophlan/trees/RAxML_bipartitions.methanomassilii.tre")
phylogenomic_tree_raw = read.tree(phylo_tree_file)
phylogenomic_tree_raw$node.label = c() # solves the "Labels are not unique" message


# Root tree and remove root for downstream analyses
outgroup_clades = c("GCA_900090055", "GCA_000195915", "GCA_900176435", "GCA_000152265", "GCA_001402945")
phylogenomic_tree_raw = phylogenomic_tree_raw %>% root(., outgroup = outgroup_clades)
phylogenomic_tree = phylogenomic_tree_raw %>% drop.tip(., outgroup_clades)

phylogenomic_tree = phytools::force.ultrametric(phylogenomic_tree)

# %%
# Create dendrogram using log2fold enrichment values
log_dendro = GE_ratio_DESeq %>%
    select(Accession, fold = log2FoldChange) %>%
    column_to_rownames("Accession") %>%
    dist() %>%
    hclust(method = "average")

# %%
# Create two groups using the enrichment dendrogram
enrich_clusters = cutree(log_dendro, k = 2)
enrich_clusters = tst %>% 
    as.factor() %>%
    as.data.frame() %>%
    rownames_to_column("col")
colnames(enrich_clusters) = c("Accession", "Clust_group")

enrich_clusters = left_join(GE_ratio_DESeq, tst_2) %>%
    select(Accession, Taxonomy, Clade, Clust_group)

enrich_clusters %>% dfhead
# Out:
# Error in eval(lhs, parent, parent): object 'tst' not found
# Traceback:
#
# 1. tst %>% as.factor() %>% as.data.frame() %>% rownames_to_column("col")
# 2. eval(lhs, parent, parent)
# 3. eval(lhs, parent, parent)

# %%
options(repr.plot.width = 12, repr.plot.height = 12)
log_phylo_dendlist = dendextend::dendlist(as.dendrogram(log_dendro), as.dendrogram(phylogenomic_tree)) %>%
    dendextend::untangle(method = "step1side") 


log_phylo_dendlist%>%
    dendextend::tanglegram(highlight_distinct_edges = FALSE,
                           common_subtrees_color_lines = FALSE, 
                           margin_inner = 8)

# %%
# Calculate correlation between enrichment dendrogram and phylogenomic tree
observed_correlation = dendextend::cor_cophenetic(log_phylo_dendlist)
observed_correlation

# %%
# Compute significance of correlation between dendrogram and phylogenomic tree by bootstraping

# Empty P value vector
permuted_cor_values = c()

# Permute dendrogram tips
for(i in 1:1000){
    # Randomly permute tips
    perm_denro = log_dendro
    perm_denro$labels = sample(perm_denro$labels)
    
    # Create dendro list
    perm_dendlist = dendextend::dendlist(as.dendrogram(perm_denro), 
                                         as.dendrogram(phylogenomic_tree)) 
    
    # Calculate correlation
    perm_cor = dendextend::cor_cophenetic(perm_dendlist)
    
    # Append to vector
    permuted_cor_values = c(permuted_cor_values, perm_cor)
}

# %%
# Calculate number of permuted values greater than observed correlation 
sum(permuted_cor_values > observed_correlation)/length(permuted_cor_values)

# %% [markdown]
# # Mmassilii in gut environments

# %% [markdown]
# ## Figure

# %%
# Metadata of animal samples
metadata_animal = metadata_raw %>%
    filter(!(id %in% c(wastewater_ids, hospital_ids))) %>%
    select(id, starts_with("environment"), starts_with("biome"), host_tax_id) %>% 
    mutate_all(.funs = c(factor)) %>%
    filter(biome_1 == "Host-associated") %>% 
    mutate(host_species = case_when(host_tax_id == 8022 ~ "Rainbow trout", 
                                    host_tax_id == 8847 ~ "Goose", 
                                    host_tax_id == 9685 ~ "Cat",
                                    host_tax_id == 9823 ~ "Pig",
                                    host_tax_id == 9852 ~ "Eurasian elk",
                                    host_tax_id == 9913 ~ "Cattle",
                                    host_tax_id == 9940 ~ "Sheep",
                                    host_tax_id == 10090 ~ "Mouse",
                                    host_tax_id == 42408 ~ "White-throated woodrat")) %>%
    mutate(host_species = case_when(environment_biome == "poultry" ~ "Poultry", 
                                    TRUE ~ host_species)) %>%
    filter(!duplicated(.))

metadata_animal %>% dfhead
# Out:
# [1] 146  12
#   id        environment_biome environment_feature environment_material biome_0
# 1 ERS723591 Faeces            Faeces              Faeces               root
# 2 ERS723612 Faeces            Faeces              Faeces               root
# 3 ERS723614 Faeces            Faeces              Faeces               root
#   biome_1         biome_2 biome_3          biome_4         biome_5 host_tax_id
# 1 Host-associated Mammals Digestive system Large intestine Fecal   9685
# 2 Host-associated Mammals Digestive system Large intestine Fecal   9685
# 3 Host-associated Mammals Digestive system Large intestine Fecal   9685
#   host_species
# 1 Cat
# 2 Cat
# 3 Cat

# %%
# Create a table of combined Clade abundances on host samples
Mmassilii_gut = Sum_clade_source %>%
    left_join(metadata_animal, ., by = c("id" = "Sample")) %>%
    select(Sample = id, Env, Clade, Abundance, biome_4, host_species) %>%
    filter(host_species != "Sheep")
# Out:
# Warning message:
# “Column `id`/`Sample` joining factor and character vector, coercing into character vector”

# %%
# Plot
plot_Clades_gut = Mmassilii_gut %>%
ggplot(., aes(x = Clade, y = Abundance, color  = Clade)) +
    geom_jitter(alpha = 0.5, position = position_jitter(width = 0.2, height = 0)) +
    facet_wrap(host_species ~ Env, nrow = 3) +
    scale_y_log10(breaks = scales::trans_breaks("log10", function(x) 10^x), 
                labels = scales::trans_format("log10", scales::math_format(10^.x))) +
    labs(y = "Abundance (%)") +
    scale_color_manual(values = clades_pallete) +
    theme_light() +
    theme(legend.position="none", 
          panel.grid.major = element_blank(), 
          panel.grid.minor = element_blank()) +
    stat_summary(fun.y = mean, 
                 fun.ymin = function(x) mean(x) - sd(x), 
                 fun.ymax = function(x) mean(x) + sd(x), 
                 geom = "pointrange", colour = "black", size = 0.2)
plot_Clades_gut                 

#Save plot
plot_file = file.path(plots_dir, "Clades_hosts_distribution.png")
save_plot(filename = plot_file, plot = plot_Clades_gut, 
          base_height = 7, base_width =7, dpi = 300)
# Out:
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 191 rows containing non-finite values (stat_summary).”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 191 rows containing non-finite values (stat_summary).”
# plot without title

# %% [markdown]
# ## Summary stats

# %%
# Count of biome (i.e. sampling site) and host
Mmassilii_gut %>%
    select(Sample, biome_4, host_species) %>%
    distinct %>%
    group_by(biome_4, host_species) %>%
    summarize(n = n())
# Out:
#    biome_4         host_species           n
# 1  Fecal           Goose                  12
# 2  Fecal           Mouse                   5
# 3  Fecal           Pig                    13
# 4  Fecal           Poultry                14
# 5  Foregut         Rainbow trout          23
# 6  Large intestine Cat                    30
# 7  Large intestine Mouse                  11
# 8  Large intestine Pig                    17
# 9  Large intestine White-throated woodrat  8
# 10 Stomach         Cattle                  8
# 11 Stomach         Eurasian elk            3

# %%
# Compare mean abundances of each clade
# On hosts with 2 sampling sites
Mmassilii_gut %>%
    filter(host_species %in% c("Pig", "Mouse")) %>%
    group_by(biome_4, Clade, host_species) %>%
    summarise(mean_abund = round(mean(Abundance), 4)) %>%
    ungroup() %>%
    arrange(host_species, biome_4)
# Out:
#    biome_4         Clade host_species mean_abund
# 1  Fecal           EX    Mouse        0.0000
# 2  Fecal           FL    Mouse        0.0185
# 3  Fecal           HA    Mouse        0.0016
# 4  Large intestine EX    Mouse        0.0000
# 5  Large intestine FL    Mouse        0.0250
# 6  Large intestine HA    Mouse        0.0009
# 7  Fecal           EX    Pig          0.0006
# 8  Fecal           FL    Pig          0.0088
# 9  Fecal           HA    Pig          0.0630
# 10 Large intestine EX    Pig          0.0002
# 11 Large intestine FL    Pig          0.0074
# 12 Large intestine HA    Pig          0.0490

# %%
# Mean abundance in all sites and all hosts
Mmassilii_gut %>%
    group_by(biome_4, Clade, host_species) %>%
    summarise(mean_abund = round(mean(Abundance), 4)) %>%
    ungroup() %>%
    arrange(biome_4, host_species)
# Out:
#    biome_4         Clade host_species           mean_abund
# 1  Fecal           EX    Goose                  0.0000
# 2  Fecal           FL    Goose                  0.0010
# 3  Fecal           HA    Goose                  0.0000
# 4  Fecal           EX    Mouse                  0.0000
# 5  Fecal           FL    Mouse                  0.0185
# 6  Fecal           HA    Mouse                  0.0016
# 7  Fecal           EX    Pig                    0.0006
# 8  Fecal           FL    Pig                    0.0088
# 9  Fecal           HA    Pig                    0.0630
# 10 Fecal           EX    Poultry                0.0005
# 11 Fecal           FL    Poultry                0.0111
# 12 Fecal           HA    Poultry                0.0072
# 13 Foregut         EX    Rainbow trout          0.0000
# 14 Foregut         FL    Rainbow trout          0.0000
# 15 Foregut         HA    Rainbow trout          0.0000
# 16 Large intestine EX    Cat                    0.0000
# 17 Large intestine FL    Cat                    0.0075
# 18 Large intestine HA    Cat                    0.0029
# 19 Large intestine EX    Mouse                  0.0000
# 20 Large intestine FL    Mouse                  0.0250
# 21 Large intestine HA    Mouse                  0.0009
# 22 Large intestine EX    Pig                    0.0002
# 23 Large intestine FL    Pig                    0.0074
# 24 Large intestine HA    Pig                    0.0490
# 25 Large intestine EX    White-throated woodrat 0.0000
# 26 Large intestine FL    White-throated woodrat 0.0082
# 27 Large intestine HA    White-throated woodrat 0.0020
# 28 Stomach         EX    Cattle                 0.0009
# 29 Stomach         FL    Cattle                 0.0066
# 30 Stomach         HA    Cattle                 0.0172
# 31 Stomach         EX    Eurasian elk           0.0009
# 32 Stomach         FL    Eurasian elk           0.0045
# 33 Stomach         HA    Eurasian elk           0.0123

# %%
# Mean abundance in all hosts combined
Mmassilii_gut %>%
    group_by(Clade) %>% #host_species
    summarise(mean_abund = round(mean(Abundance), 4)) %>%
    ungroup() %>%
    arrange(Clade, -mean_abund)

# Mean abundance of each clade on each host
Mmassilii_gut %>%
    group_by(Clade, host_species) %>%
    summarise(mean_abund = round(mean(Abundance), 4)) %>%
    ungroup() %>%
    arrange(host_species, -mean_abund)

# Mean Methanomassilii abundance on each host
Mmassilii_gut %>%
    group_by(host_species) %>%
    summarise(mean_abund = round(mean(Abundance), 4)) %>%
    ungroup() %>%
    arrange(mean_abund)
# Out:
#   Clade mean_abund
# 1 EX    0.0002
# 2 FL    0.0078
# 3 HA    0.0142
#    Clade host_species           mean_abund
# 1  FL    Cat                    0.0075
# 2  HA    Cat                    0.0029
# 3  EX    Cat                    0.0000
# 4  HA    Cattle                 0.0172
# 5  FL    Cattle                 0.0066
# 6  EX    Cattle                 0.0009
# 7  HA    Eurasian elk           0.0123
# 8  FL    Eurasian elk           0.0045
# 9  EX    Eurasian elk           0.0009
# 10 FL    Goose                  0.0010
# 11 EX    Goose                  0.0000
# 12 HA    Goose                  0.0000
# 13 FL    Mouse                  0.0230
# 14 HA    Mouse                  0.0011
# 15 EX    Mouse                  0.0000
# 16 HA    Pig                    0.0550
# 17 FL    Pig                    0.0080
# 18 EX    Pig                    0.0004
# 19 FL    Poultry                0.0111
# 20 HA    Poultry                0.0072
# 21 EX    Poultry                0.0005
# 22 EX    Rainbow trout          0.0000
# 23 FL    Rainbow trout          0.0000
# 24 HA    Rainbow trout          0.0000
# 25 FL    White-throated woodrat 0.0082
# 26 HA    White-throated woodrat 0.0020
# 27 EX    White-throated woodrat 0.0000
#   host_species           mean_abund
# 1 Rainbow trout          0.0000
# 2 Goose                  0.0003
# 3 White-throated woodrat 0.0034
# 4 Cat                    0.0035
# 5 Eurasian elk           0.0059
# 6 Poultry                0.0063
# 7 Mouse                  0.0080
# 8 Cattle                 0.0082
# 9 Pig                    0.0211

# %% [markdown]
# ## Prevalence and abundance of individual taxa on hosts

# %%
# Table of Methanomassilii abundances
Mmassilii_gut_taxon = KUniq_relabund %>%
    select(-Clade) %>%
    gather(Sample, Abundance, -Accession) %>%
    left_join(Assemblies_table, by = c("Accession" = "Assembly")) 

# Add metadata
Mmassilii_gut_taxon = Mmassilii_gut_taxon %>%
    left_join(metadata_animal, ., by = c("id" = "Sample")) %>%
    select(Accession, Taxonomy, Sample = id, Clade, Abundance, biome_4, host_species) %>%
    filter(host_species != "Sheep")

Mmassilii_gut_taxon = Mmassilii_gut_taxon %>% 
    mutate(Taxonomy = str_remove(Taxonomy, "uncultured")) %>%
    arrange(Clade, Taxonomy) %>% 
    mutate(Taxonomy = factor(Taxonomy),
           Taxonomy = str_replace_all(Taxonomy, "_", " "),
           Taxonomy = fct_inorder(Taxonomy))
# Out:
# Warning message:
# “Column `id`/`Sample` joining factor and character vector, coercing into character vector”

# %%
# Function to plot abundances on the gut
plt_fun_gut = function (environment, abundance_table) 
{
    clades_pallete = c("#7f7db9", "#15a783", "#e16f0b")
    plt = abundance_table %>% filter(host_species == environment) %>% 
        ggplot(., aes(x = Taxonomy, y = Abundance, color = Clade)) +
        geom_jitter(alpha = 0.7, position = position_jitter(width = 0.2, height = 0)) +
        scale_y_log10(breaks = scales::trans_breaks("log10", function(x) 10^x), 
                      labels = scales::trans_format("log10",scales::math_format(10^.x))) +
        theme_light() +
        scale_color_manual(values = clades_pallete) +
        theme(axis.text.x = element_text(angle = 45, hjust = 1), 
              panel.grid.major = element_blank(), panel.grid.minor = element_blank()) +
        labs(x = "Taxon", y = "Abundance (%)", title = environment) +
        stat_summary(fun.data = mean_sdl, fun.args = list(mult = 1), 
                     geom = "pointrange", color = "black", size = 0.2) +
        coord_flip()
}

# %%
options(repr.plot.width = 18, repr.plot.height =  1.5*length(plots_hosts))

hosts_order = Mmassilii_gut_taxon %>%
    pull(host_species) %>%
    unique() %>%
    sort

plots_hosts = map(hosts_order, function(x) plt_fun_gut(x, Mmassilii_gut_taxon))

Mmassilii_host_distribution = plot_grid(plotlist = plots_hosts, ncol = 3)
Mmassilii_host_distribution
                  
# Save plot
plot_file = file.path(plots_dir, "Mmassilii_hosts_distribution.png")
save_plot(filename = plot_file, plot = Mmassilii_host_distribution, 
          base_height = 1.5*length(plots_hosts), base_width = 18, dpi = 300)
# Out:
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 720 rows containing non-finite values (stat_summary).”Warning message:
# “Removed 2 rows containing missing values (geom_pointrange).”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 66 rows containing non-finite values (stat_summary).”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 11 rows containing non-finite values (stat_summary).”Warning message:
# “Removed 1 rows containing missing values (geom_pointrange).”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 343 rows containing non-finite values (stat_summary).”Warning message:
# “Removed 3 rows containing missing values (geom_pointrange).”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 423 rows containing non-finite values (stat_summary).”Warning message:
# “Removed 5 rows containing missing values (geom_pointrange).”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 240 rows containing non-finite values (stat_summary).”Warning message:
# “Removed 1 rows containing missing values (geom_pointrange).”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 235 rows containing non-finite values (stat_summary).”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 663 rows containing non-finite values (stat_summary).”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 157 rows containing non-finite values (stat_summary).”Warning message:
# “Removed 1 rows containing missing values (geom_pointrange).”
# plot without title

# %% [markdown]
# ## Outliers

# %%
# Compare the mean abundance of each outlier with the mean abundance of the clade without outliers
# on each animal host

# Outlier vector
FL_outliers = c("GCA_002508545", "GCA_001421185", "GCA_000404225", "GCA_000308215", "GCA_002498285")

# Mean abundance of clade without outliers on each host
Mmassilii_nFL_abund = Mmassilii_gut_taxon %>%
    filter(Clade == "FL", !(Accession %in% FL_outliers)) %>%
    group_by(host_species) %>%
    summarise(Clade_abund = round(mean(Abundance), 4)) %>%
    ungroup()

# Mean abundance of each outlier on each host
Mmassilii_gut_taxon %>%
    filter(Accession %in% FL_outliers) %>%
    group_by(Accession, host_species) %>%
    summarise(mean_abund = round(mean(Abundance), 4)) %>%
    ungroup() %>%
    arrange(host_species, -mean_abund) %>%
    left_join(Mmassilii_nFL_abund) %>%
    mutate(higher = mean_abund >= Clade_abund)
# Out:
# Joining, by = "host_species"
#    Accession     host_species           mean_abund Clade_abund higher
# 1  GCA_002508545 Cat                    0.0030     0e+00        TRUE
# 2  GCA_001421185 Cat                    0.0026     0e+00        TRUE
# 3  GCA_000308215 Cat                    0.0018     0e+00        TRUE
# 4  GCA_000404225 Cat                    0.0000     0e+00        TRUE
# 5  GCA_002498285 Cat                    0.0000     0e+00        TRUE
# 6  GCA_002508545 Cattle                 0.0023     2e-04        TRUE
# 7  GCA_001421185 Cattle                 0.0017     2e-04        TRUE
# 8  GCA_000308215 Cattle                 0.0009     2e-04        TRUE
# 9  GCA_002498285 Cattle                 0.0004     2e-04        TRUE
# 10 GCA_000404225 Cattle                 0.0000     2e-04       FALSE
# 11 GCA_001421185 Eurasian elk           0.0011     2e-04        TRUE
# 12 GCA_002508545 Eurasian elk           0.0010     2e-04        TRUE
# 13 GCA_000308215 Eurasian elk           0.0006     2e-04        TRUE
# 14 GCA_002498285 Eurasian elk           0.0003     2e-04        TRUE
# 15 GCA_000404225 Eurasian elk           0.0000     2e-04       FALSE
# 16 GCA_002508545 Goose                  0.0009     0e+00        TRUE
# 17 GCA_001421185 Goose                  0.0001     0e+00        TRUE
# 18 GCA_000308215 Goose                  0.0000     0e+00        TRUE
# 19 GCA_000404225 Goose                  0.0000     0e+00        TRUE
# 20 GCA_002498285 Goose                  0.0000     0e+00        TRUE
# 21 GCA_001421185 Mouse                  0.0214     0e+00        TRUE
# 22 GCA_002508545 Mouse                  0.0010     0e+00        TRUE
# 23 GCA_000308215 Mouse                  0.0002     0e+00        TRUE
# 24 GCA_002498285 Mouse                  0.0002     0e+00        TRUE
# 25 GCA_000404225 Mouse                  0.0000     0e+00        TRUE
# 26 GCA_001421185 Pig                    0.0036     2e-04        TRUE
# 27 GCA_002508545 Pig                    0.0020     2e-04        TRUE
# 28 GCA_000308215 Pig                    0.0009     2e-04        TRUE
# 29 GCA_002498285 Pig                    0.0005     2e-04        TRUE
# 30 GCA_000404225 Pig                    0.0000     2e-04       FALSE
# 31 GCA_001421185 Poultry                0.0054     3e-04        TRUE
# 32 GCA_002508545 Poultry                0.0019     3e-04        TRUE
# 33 GCA_002498285 Poultry                0.0010     3e-04        TRUE
# 34 GCA_000308215 Poultry                0.0007     3e-04        TRUE
# 35 GCA_000404225 Poultry                0.0001     3e-04       FALSE
# 36 GCA_000308215 Rainbow trout          0.0000     0e+00        TRUE
# 37 GCA_000404225 Rainbow trout          0.0000     0e+00        TRUE
# 38 GCA_001421185 Rainbow trout          0.0000     0e+00        TRUE
# 39 GCA_002498285 Rainbow trout          0.0000     0e+00        TRUE
# 40 GCA_002508545 Rainbow trout          0.0000     0e+00        TRUE
# 41 GCA_001421185 White-throated woodrat 0.0063     1e-04        TRUE
# 42 GCA_002508545 White-throated woodrat 0.0009     1e-04        TRUE
# 43 GCA_000308215 White-throated woodrat 0.0005     1e-04        TRUE
# 44 GCA_002498285 White-throated woodrat 0.0002     1e-04        TRUE
# 45 GCA_000404225 White-throated woodrat 0.0000     1e-04       FALSE

# %%
# Compare the mean abundance of each outlier with the mean abundance of the clade without outliers
# on each animal host

# Outlier vector
HA_outliers = "GCA_000800805"

# Mean abundance of clade without outliers on each host
Mmassilii_nHA_abund = Mmassilii_gut_taxon %>%
    filter(Clade == "HA", !(Accession %in% HA_outliers)) %>%
    group_by(host_species) %>%
    summarise(Clade_abund = round(mean(Abundance), 4)) %>%
    ungroup()

# Mean abundance of each outlier on each host
Mmassilii_gut_taxon %>%
    filter(Accession %in% HA_outliers) %>%
    group_by(Accession, host_species) %>%
    summarise(mean_abund = round(mean(Abundance), 4)) %>%
    ungroup() %>%
    arrange(host_species, -mean_abund) %>%
    left_join(Mmassilii_nHA_abund) %>%
    mutate(higher = mean_abund <= Clade_abund)
# Out:
# Joining, by = "host_species"
#   Accession     host_species           mean_abund Clade_abund higher
# 1 GCA_000800805 Cat                    0e+00      0.0002      TRUE
# 2 GCA_000800805 Cattle                 1e-04      0.0011      TRUE
# 3 GCA_000800805 Eurasian elk           4e-04      0.0008      TRUE
# 4 GCA_000800805 Goose                  0e+00      0.0000      TRUE
# 5 GCA_000800805 Mouse                  0e+00      0.0001      TRUE
# 6 GCA_000800805 Pig                    4e-04      0.0036      TRUE
# 7 GCA_000800805 Poultry                0e+00      0.0005      TRUE
# 8 GCA_000800805 Rainbow trout          0e+00      0.0000      TRUE
# 9 GCA_000800805 White-throated woodrat 0e+00      0.0001      TRUE

# %% [markdown]
# # Metadata table of used samples

# %%
# Export metadata table
MGnify_metagenomes_metadata = metadata_raw %>% 
    filter(id %in% Sum_clade_env$Sample) %>%
    group_by(id) %>%
    mutate(rank = row_number(id)) %>%
    ungroup %>% 
    filter(rank == 1) %>%
    select(id, run, biosample, accession, study, starts_with("biome"))

write_tsv(MGnify_metagenomes_metadata, "/ebio/abt3_projects/vadinCA11/data/V11/Mmassilii_distribution/tables/MGnify_metagenomes_metadata.tsv")

# %%
metadata_raw %>% colnames

# %% [markdown]
# # Session info

# %%
sessionInfo()
# Out:
# R version 3.5.1 (2018-07-02)
# Platform: x86_64-conda_cos6-linux-gnu (64-bit)
# Running under: Ubuntu 18.04.5 LTS
#
# Matrix products: default
# BLAS/LAPACK: /ebio/abt3_projects/software/miniconda3_gt4.4/envs/UpSetR_2/lib/R/lib/libRlapack.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] parallel  stats4    stats     graphics  grDevices utils     datasets
# [8] methods   base
#
# other attached packages:
#  [1] ape_5.3                     DESeq2_1.22.1
#  [3] SummarizedExperiment_1.12.0 DelayedArray_0.8.0
#  [5] BiocParallel_1.16.6         matrixStats_0.55.0
#  [7] Biobase_2.42.0              GenomicRanges_1.34.0
#  [9] GenomeInfoDb_1.18.1         IRanges_2.16.0
# [11] S4Vectors_0.20.1            BiocGenerics_0.28.0
# [13] broom_0.5.2                 caret_6.0-84
# [15] cowplot_1.0.0               vegan_2.5-5
# [17] lattice_0.20-38             permute_0.9-5
# [19] reshape2_1.4.3              forcats_0.4.0
# [21] stringr_1.4.0               dplyr_0.8.3
# [23] purrr_0.3.2                 readr_1.3.1
# [25] tidyr_0.8.3                 tibble_2.1.3
# [27] tidyverse_1.2.1             ggplot2_3.2.1
#
# loaded via a namespace (and not attached):
#   [1] readxl_1.3.1            uuid_0.1-2              backports_1.1.4
#   [4] Hmisc_4.2-0             fastmatch_1.1-0         plyr_1.8.4
#   [7] igraph_1.2.4.1          repr_1.0.1              lazyeval_0.2.2
#  [10] splines_3.5.1           digest_0.6.20           foreach_1.4.7
#  [13] htmltools_0.3.6         magrittr_1.5            phytools_0.7-47
#  [16] checkmate_1.9.4         memoise_1.1.0           cluster_2.1.0
#  [19] recipes_0.1.6           annotate_1.60.1         modelr_0.1.5
#  [22] gower_0.2.1             colorspace_1.4-1        blob_1.2.0
#  [25] rvest_0.3.4             haven_2.1.1             xfun_0.8
#  [28] crayon_1.3.4            RCurl_1.98-1.1          jsonlite_1.6
#  [31] genefilter_1.64.0       zeallot_0.1.0           survival_2.44-1.1
#  [34] phangorn_2.5.5          iterators_1.0.12        glue_1.3.1
#  [37] gtable_0.3.0            ipred_0.9-9             zlibbioc_1.28.0
#  [40] XVector_0.22.0          maps_3.3.0              scales_1.0.0
#  [43] DBI_1.0.0               Rcpp_1.0.2              plotrix_3.7-6
#  [46] xtable_1.8-4            htmlTable_1.13.2        foreign_0.8-71
#  [49] bit_1.1-14              Formula_1.2-3           lava_1.6.5
#  [52] prodlim_2018.04.18      animation_2.6           htmlwidgets_1.3
#  [55] httr_1.4.1              RColorBrewer_1.1-2      acepack_1.4.1
#  [58] pkgconfig_2.0.2         XML_3.98-1.20           nnet_7.3-12
#  [61] locfit_1.5-9.1          tidyselect_0.2.5        labeling_0.3
#  [64] rlang_0.4.0             AnnotationDbi_1.44.0    munsell_0.5.0
#  [67] cellranger_1.1.0        tools_3.5.1             cli_1.1.0
#  [70] generics_0.0.2          RSQLite_2.1.2           evaluate_0.14
#  [73] ModelMetrics_1.2.2      knitr_1.24              bit64_0.9-7
#  [76] nlme_3.1-141            xml2_1.2.2              compiler_3.5.1
#  [79] rstudioapi_0.10         clusterGeneration_1.3.4 geneplotter_1.60.0
#  [82] stringi_1.4.3           IRdisplay_0.7.0         Matrix_1.2-17
#  [85] vctrs_0.2.0             pillar_1.4.2            combinat_0.0-8
#  [88] data.table_1.12.2       bitops_1.0-6            R6_2.4.0
#  [91] latticeExtra_0.6-28     gridExtra_2.3           codetools_0.2-16
#  [94] gtools_3.8.1            MASS_7.3-51.4           assertthat_0.2.1
#  [97] withr_2.1.2             mnormt_1.5-5            GenomeInfoDbData_1.2.1
# [100] expm_0.999-4            mgcv_1.8-28             hms_0.5.0
# [103] quadprog_1.5-7          grid_3.5.1              rpart_4.1-15
# [106] timeDate_3043.102       IRkernel_1.0.2          coda_0.19-3
# [109] class_7.3-15            pbdZMQ_0.3-3            scatterplot3d_0.3-41
# [112] numDeriv_2016.8-1.1     lubridate_1.7.4         base64enc_0.1-3

# %% [markdown]
# # Debug
